# %%
from rdkit.Chem import RDConfig
import os
import sys
sys.path.append(os.path.join(RDConfig.RDContribDir, 'SA_Score'))
import sascorer

# %%
from transformers import pipeline, Aut
from rdkit import Chem
from rdkit.Chem.rdchem import Mol
from rdkit.Chem import Descriptors

from tqdm.auto import tqdm

# %%
pipe = pipeline("text-generation", model="msb-roshan/molgpt")
# Out:
# Device set to use cpu

# %%
s = []
for i in tqdm(range(100)):
    s.append(pipe('', num_workers=12))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
def smiles_valid(smiles_str: str) -> bool:
    try:
        mol = Chem.MolFromSmiles(smiles_str)
    except Exception:
        return False
    
    if mol is None:
        return False

    return True

aromatic_amine_smarts = Chem.MolFromSmarts('[N,n;H1,H0;$(N-[a])]-[a]') # этот шаблон ищет ароматические амины, в которых азот связан с ароматическим кольцом
phenol_smarts = Chem.MolFromSmarts('[OH]-[c,C]1:[c,C]:[c,C]:[c,C]:[c,C]:[c,C]:1') # этот шаблон ищет фенолы, в которых гидроксильная группа связана с ароматическим кольцом


def is_aromatic_amine_or_phenol(smiles_str: str) -> bool:
    mol = Chem.MolFromSmiles(smiles_str)
    return mol.HasSubstructMatch(phenol_smarts) or \
           mol.HasSubstructMatch(aromatic_amine_smarts)


def has_radical(mol: Mol) -> bool:
    for atom in mol.GetAtoms():
        if atom.GetNumRadicalElectrons() > 0:
            return True
    return False


def neutral_and_no_radical(smiles_str: str) -> bool:
    mol = Chem.MolFromSmiles(smiles_str)
    return Chem.GetFormalCharge(mol) == 0 and not has_radical(mol)

def mol_weight(smiles_str: str) -> float:
    mol = Chem.MolFromSmiles(smiles_str)
    return Descriptors.MolWt(mol)

allowed_atoms = {'C', 'H', 'O', 'N', 'P', 'S'}

def only_allowed_atoms(smiles_str: str) -> bool:
    mol = Chem.MolFromSmiles(smiles_str)
    for atom in mol.GetAtoms():
        if atom.GetSymbol() not in allowed_atoms:
            return False
    return True

def log_p(smiles_str: str) -> float:
    mol = Chem.MolFromSmiles(smiles_str)
    logp = Descriptors.MolLogP(mol)
    return logp

def sa_score(smiles_str) -> float:
    mol = Chem.MolFromSmiles(smiles_str)
    return sascorer.calculateScore(mol)

# %%
import pandas as pd

rows = []
for el in s:
    generated_text = el[0]['generated_text']
    valid = smiles_valid(generated_text)
    
    row_data = {
        'generated_text': generated_text,
        'valid': valid
    }
    
    if valid:
        row_data.update({
            'sa_score': sa_score(generated_text),
            'log_p': log_p(generated_text),
            'only_allowed_atoms': only_allowed_atoms(generated_text),
            'mol_weight': mol_weight(generated_text),
            'neutral_and_no_radical': neutral_and_no_radical(generated_text),
            'is_aromatic_amine_or_phenol': is_aromatic_amine_or_phenol(generated_text)
        })
    
    rows.append(row_data)

# Создаем DataFrame и явно задаем порядок колонок
df = pd.DataFrame(rows, columns=[
    'generated_text',
    'valid',
    'sa_score',
    'log_p',
    'only_allowed_atoms',
    'mol_weight',
    'neutral_and_no_radical',
    'is_aromatic_amine_or_phenol'
])

# Для невалидных SMILES заполняем NaN
df = df.where(df['valid'], pd.NA)
# Out:
# [19:27:52] SMILES Parse Error: extra open parentheses while parsing: C(=O)NC(C
# [19:27:52] SMILES Parse Error: check for mistakes around position 8:
# [19:27:52] C(=O)NC(C
# [19:27:52] ~~~~~~~^
# [19:27:52] SMILES Parse Error: Failed parsing SMILES 'C(=O)NC(C' for input: 'C(=O)NC(C'
# [19:27:52] SMILES Parse Error: unclosed ring for input: 'CC1CN'
# [19:27:52] SMILES Parse Error: unclosed ring for input: 'CCC(=O)O.CCC1'
# [19:27:52] SMILES Parse Error: unclosed ring for input: 'C(=O)NC1'
# [19:27:52] SMILES Parse Error: syntax error while parsing: CC(N)=S.N#
# [19:27:52] SMILES Parse Error: check for mistakes around position 10:
# [19:27:52] CC(N)=S.N#
# [19:27:52] ~~~~~~~~~^
# [19:27:52] SMILES Parse Error: Failed parsing SMILES 'CC(N)=S.N#' for input: 'CC(N)=S.N#'
# [19:27:52] SMILES Parse Error: unclosed ring for input: 'C(=O)NCC1'
# [19:27:52] SMILES Parse Error: extra open parentheses while parsing: c1nc(C
# [19:27:52] SMILES Parse Error: check for mistakes around position 5:
# [19:27:52] c1nc(C
# [19:27:52] ~~~~^
# [19:27:52] SMILES Parse Error: Failed parsing SMILES 'c1nc(C' for input: 'c1nc(C'
# [19:27:52] SMILES Parse Error: unclosed ring for input: 'C(=O)NC1'
# [19:27:52] SMILES Parse Error: extra open parentheses while parsing: c1nc(C
# [19:27:52] SMILES Parse Error: check for mistakes around position 5:
# [19:27:52] c1nc(C
# [19:27:52] ~~~~^
# [19:27:52] SMILES Parse Error: Failed parsing SMILES 'c1nc(C' for input: 'c1nc(C'
# [19:27:52] SMILES Parse Error: unclosed ring for input: 'CC1=N'
# [19:27:52] SMILES Parse Error: extra open parentheses while parsing: c1nc(C
# [19:27:52] SMILES Parse Error: check for mistakes around position 5:
# [19:27:52] c1nc(C
# [19:27:52] ~~~~^
# [19:27:52] SMILES Parse Error: Failed parsing SMILES 'c1nc(C' for input: 'c1nc(C'
# [19:27:52] SMILES Parse Error: unclosed ring for input: 'C(=O)NC1'
# [19:27:52] SMILES Parse Error: extra open parentheses while parsing: C(=O)NC(C
# [19:27:52] SMILES Parse Error: check for mistakes around position 8:
# [19:27:52] C(=O)NC(C
# [19:27:52] ~~~~~~~^
# [19:27:52] SMILES Parse Error: Failed parsing SMILES 'C(=O)NC(C' for input: 'C(=O)NC(C'
# [19:27:52] SMILES Parse Error: unclosed ring for input: 'CC(N)=S.CC1'
# [19:27:52] SMILES Parse Error: unclosed ring for input: 'C(=O)N1CCCC'
# [19:27:52] SMILES Parse Error: unclosed ring for input: 'C(=O)NC1'
# [19:27:52] SMILES Parse Error: unclosed ring for input: 'C(=O)NC1'
# [19:27:52] SMILES Parse Error: unclosed ring for input: 'C(=O)N1CCCC'
# [19:27:52] SMILES Parse Error: syntax error while parsing: C(=O)N1CCC(
# [19:27:52] SMILES Parse Error: check for mistakes around position 11:
# [19:27:52] C(=O)N1CCC(
# [19:27:52] ~~~~~~~~~~^
# [19:27:52] SMILES Parse Error: Failed parsing SMILES 'C(=O)N1CCC(' for input: 'C(=O)N1CCC('
# [19:27:52] SMILES Parse Error: unclosed ring for input: 'C(=O)NC1'
# [19:27:52] SMILES Parse Error: syntax error while parsing: C(=O)C(
# [19:27:52] SMILES Parse Error: check for mistakes around position 7:
# [19:27:52] C(=O)C(
# [19:27:52] ~~~~~~^
# [19:27:52] SMILES Parse Error: Failed parsing SMILES 'C(=O)C(' for input: 'C(=O)C('
# [19:27:52] SMILES Parse Error: extra open parentheses while parsing: C(=O)N(C
# [19:27:52] SMILES Parse Error: check for mistakes around position 7:
# [19:27:52] C(=O)N(C
# [19:27:52] ~~~~~~^
# [19:27:52] SMILES Parse Error: Failed parsing SMILES 'C(=O)N(C' for input: 'C(=O)N(C'
# [19:27:52] SMILES Parse Error: syntax error while parsing: c1nnc(-
# [19:27:52] SMILES Parse Error: check for mistakes around position 7:
# [19:27:52] c1nnc(-
# [19:27:52] ~~~~~~^
# [19:27:52] SMILES Parse Error: Failed parsing SMILES 'c1nnc(-' for input: 'c1nnc(-'
# [19:27:52] SMILES Parse Error: extra open parentheses while parsing: c1nc(C
# [19:27:52] SMILES Parse Error: check for mistakes around position 5:
# [19:27:52] c1nc(C
# [19:27:52] ~~~~^
# [19:27:52] SMILES Parse Error: Failed parsing SMILES 'c1nc(C' for input: 'c1nc(C'

# %%
df['valid'].fillna(False, inplace=True)

# %%
df['valid'].astype('int').mean()
# Out:
# np.float64(0.76)

# %%
print('\n\n\n'.join(df['generated_text'][df['generated_text'].notna()].tolist()))
# Out:
# CC(N)=S.CCC(C) c1ccccc1.O=C1 CCC c2n c3cc(C#C c4ccccn4)ccc3 c(=O)n2 CC1.O=c1 c2ccc(C#C c3ccccn3)cc2 nc2n1 CC1 CCCN C21.O=c1 c2ccc(C#C c3ccccn3)cc2 nc2n1 CCC1 CCCN C21.O=c1 c2ccc(C#C c3ccccn3)cc2 nc2n1 CCC1 CCCN C21.O=c1 c2ccc(C#C c3ccccn3)cc2 nc2n1 CCC1 N CCC21.O=c1 c2ccc(C#C c3ccccn3)cc2 nc2n1 CCC1 NCCN C21.O=c1 c2ccc(C#C c3ccccn3)cc2 nc2n1
#
#
# C(=O)c1ccccc1 Br.CCC (C(=O) C1CCCCC1) C(=O)c1ccccc1 OC1CCCCO1.COC(=O) CC(=O)c1ccccc1 OC1CCCCO1.COC(=O) CC(=O)c1ccccc1 OC1CCCCO1.COC(=O) Cc1ccccc1 OC1CCCCO1.O=C(C (C(=O)c1ccccc1) =C([O-]) c1ccccc1)c1ccccc1 OC1CCCCO1.O=C1 CCCN1 c1ccccc1 OC1CCCCO1.O=C1 CCCN1 c1ccccc1 OC1CCCCO1.O=C1 CCCN1 c1ccccc1 OC1CCCCO1.[Br-].[ M g+2].[ Z n]. c1ccoc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1cc
# C(=O)Nc1ccccc1 C#N.CC(C) CC c1cc(C(F)(F)F)ccc1 C(=O)NC1 (c2ccccc2) CC(F)(F) C1. NC(=O) c1ccccc1- c1ccc(C(F)(F)F)cc1 CC(=O)N c1ccccc1. O=C(Cc1ccc(F)cc1) Nc1ccccc1 C(=O)NC1CC1.O c1ccc(C(F)(F)F)cc1 -c1ccccc1 C(F)(F)F.[2H] I ([2H])([2H]) (Cl) C(=O)N c1ccccc1C.[2H] [I-] ([2H])([2H]) C([2H]) (Cl) C(=O)N c1ccccc1C.[2H] [I-] ([2H])([2H]) C([2H]) (Cl) C(=O)N c1ccccc1C.[2H] [I-] C([2H])(C) I.[2H] [I-] C1 (NC(=O)
#
#
# CC(=O)OC (C(C)(C)O) C(C) CCC1C.CO c1ccc(C)cc1Cl.CO c1ccc(NC(C)=O)cc1.CO c1ccc(NC(C)=O)cc1 OC(C)C (C)C.C c1cccc(O)c1 P(C)(C)=O.O=C(O) C1CCCCC1.O =O.O= c1cc(- c2ccc(O)c(O)c2) o c2cc(O)cc(O) c12.[2H] P =S. c1ccc2[nH] cnc2c1. c1ccc2[nH] cnc2c1.c1ccc2c(c1) CCCC2.c1ccc2c(c1) CCCC2.c1ccc2c(c1) CN C=C2.c1ccc2c(c1) COc1ccccc1 C2. c1ccc2c(c1)OCO2.c1ccccc1. c1ccc2ccccc2c1. c1ccccc1
#
#
# CC(N) =C1 C(=N) C(C) F.CCC. COc1cc(C)cc (F)c1.[HH]. SS. SS c1ccccn1. SS c1ccccn1. SS c1ccncc1. SS c1ccncc1. SS c1ccncc1. SS c1ccncc1. SS c1ccncc1. SS c1ccnnc1. SS c1cnccn1. SS c1cnccn1. SS c1ncccn1. SS c1nccs1.
#
#
# CC(=O)OC (C(C)(C) CCC2 OCCO 2)C1(C)C.COC(=O) CC1C (C(=O)OC) CCCC1 (C)CC =O.COC(=O) CC1C (C(=O)OC) CCCC1 (C)CC =O.COC(=O) CC1C (C(=O)OC) CCCC1 (C)CC =O. COC(=O)C1 CCCC (C(=O)OC) C1(C)C =O.COC(=O)C1 CCCC ([N+](=O)[O-]) C1(C)C =O. COC(=O)C1 CCCC CCC1=O.COC(=O)C1 CCCC =CC1=O.COC(=O) [C@@H]1CCCC C=C1 C. COC(=O)C(C)C #N.COC(=O) /C=C/ C(=O)OC.O=C(O)
#
#
# CC(C(=O)O) CN1C(=O)OC(C)(C)C.CC(C)(C)OC(=O) CC1 CC(NC(=O)OC(C)(C)C) CN1 C(=O)OCC1c2ccccc2-c2ccccc21.CC (NC(=O) CC1 CC(NC(=O)OC(C)(C)C) CN1 C(=O)OCC1c2ccccc2-c2ccccc21) C(=O)O.CC (N=[N+]=[N-]) C(=O)O N1C(=O)CCC1=O.CC (N=[N+]=[N-]) C(=O)O N1C(=O)CCC1=O.Cl.N =N N=N Cl.O=C(O) C( CC(=O)N1 CC(N 2C(=O) C=CC2=O) C1) CC1 CC(Br) C(=O)O1.O=C( CCl) ON1 CC(O) C(Br) C1.O=C(O) CC1 CC(N 2C(=O)c3ccccc3C2=O) C1.O=C1 NC2 (
#
#
# CC(N) C1(C)C.Cl.O=C(O)c1ccccc1.O=C(O)c1ccccc1.O=CO.c1ccccc1.[HH].[HH].[HH].[N-]=[N+]=N c1ccccc1 C1 CC(CC(=O)O) C(N) CC1(N) C(=O)O.[N-]=[N+]=N c1ccccc1 C1 CC(CC(=O)O) C(N) CCC1 C(=O)OC(C)(C)C.[N-]=[N+]=N c1ccccc1 C1 CC(CC(=O)O) C(N) CC1 C(=O)OC(C)(C)C.[N-]=[N+]=N c1ccccc1 C1 CC(CC(=O)O) C(N) CC1(N) C(=O)O.[N-]=[N+] c1ccccc1 C1 C[C@@H](N) C(N) CC1 C(=O)[O-].[N-]=[N+] c1ccccc1 C1 C[C@@H](N) C(N) CC12
#
#
# C(=O)c1ccccc1 C(F)(F)F.CCC # CCC(C)OC(=O) C(c1ccccc1) C(F)(F)F.CCC # CCC(C)OC(=O) C(c1ccccc1) C(F)(F)F.CCC OC(=O) C(c1ccccc1) C(F)(F)F.CCCC OC(=O) C(c1ccccc1) C(F)(F)F.CCC OC(=O) C(c1ccccc1) C(F)(F)F.CCC OC(=O) C(CCc1ccccc1) C(F)(F)F.CCC OC(=O) C(CCc1ccccc1) C(F)(F)F.CCC OC(=O) C(CCc1ccccc1) C(F)(F)F.CCC OC(=O) C(CCc1ccccc1) C(F)(F)F.CCC OC(=O) C(CCc1ccccc1) C(F)(F)F.CCC OC(=O) C(CCc1ccccc1) C(F)(F)F.CCC
#
#
# C(=O)NCC (CC) (C(=O)O) C1C.CO c1ccc(NC(=O) C(C (N) C=O) C2(C) CCN C2=O)cc1.O=C1 NCC (CC 2CCCCC2) N1.[HH].[Na+].[OH-]. c1ccc2ccccc2c1.c1ccc2 c(N CC3CC3) n[nH]c2c1.c1ccc2 c(N CC3CC3) n[nH]c2c1. c1ccc2ccccc2c1.c1ccc2 c(N CC3CC3) n[nH]c2c1.c1ccc2 c(N CC3CC3) n[nH]c2c1.c1ccc2 c(N CCN3CCOCC3) n[nH]c2c1.c1ccc2 c(N CCN3CCOCC3) n[nH]c2c1.c1ccc2 n[nH]
#
#
# C(=O)Nc1ccccc1 C(=O)OC c1o c(=O)o c1-c1ccccc1 C(=O)N CC(=O)N1CCCC1 C(=O)OC c1o c(=O)o c1-c1ccccc1 C(=O)N CC(=O)N1CCCC1 C(=O)OC c1o c(=O)oc1 C1CCCCC1 C(=O)OC c1o c(=O)o c1-c1ccccc1 C(=O)N CC(=O)N1CCCC1 C(=O)OC1 (CCC OC(=O) C(NC(=O) C2CCCN2 C(C)=O) C(C)C) CCCCC1.O=C1 C c2c([nH] c(-c3ccccc3) c2C(=O) c2ccc(O [C@H]3 O[C@H](CO)[C@H](O)[C@H](O)[C@H]3O) cc2) C(=O) c2ccc(O [C@H]3O [C@@H](CO [C@@H]4 O[C@H](CO)[C@H](O)[C@H](O) C4O) [C@H](O)[C@@H](O) [C@@H]3
#
#
# S(=O)(=O)c1ccc(C)cc1.CO CCN S(=O)(=O)c1ccccc1 C.C c1ccc(S(=O)(=O)N C2CCCCC2)cc1 C.[I-].[I-].[ I-].[ V +3].c1ccncc1.c1ccncc1.c1ccncc1.c1ccncc1. c1cnn(- c2ccncc2)c1. c1cn[nH]c1. c1cnccn1. c1cn[nH] n1. c1cn o c1.c1cn s c1. c1cscn1. c1ncc[nH]1. c1nc[nH] n1. c1nco n1. c1nn[nH]n1. c1nn co1. c1nncs1. c1nncs1. c1nn
#
#
# CC(=O)OC (C (C)C =C c2ccc(F) c(O c3ccccc3)c2)C1 O C(=O)N(C)C (C)C =C c1cccc(Cl)c1.CC(C) C(OC(=O) C1 C(C=C c2ccc(F) c(O c3ccccc3)c2)C1 C(=O)OC (C(C)C) C(C) C(O C(=O)N(C)C) C(=O)O C1CCCCC1) C(=O)O C1CCCCC1.CNC(=O) OC(C)O c1cc(C (C c2ccc(C)cc2) C(C)C)ccc1OC (C)C(C) C( c1ccc(OC(C)=O) c(OC)c1) C(C)C.COc1ccc(C (O) CC(C) C(=O)OC(C) C( c2ccc(OC(C)=O) c(OC)c2) C(C)C)cc1 OC(=O)C(C) OC(
#
#
# C(=O)NCC c1ccc(OC)cc1 O c1ccc(C(F)(F)F)cn1.O c1cccc(C(F)(F)F)c1.[A c ].[B ].[B] [B] B(B([B])[B]) B(B([B])[B]) B([B])[B].c1ccc2c(c1) ncn2 C1CCCCC1. c1ccc2nc(C 3CCC(N 4CCOCC4)CC3) ccc2c1.c1cnc2c(c1) CCCC2. c1nc(C2CC2) cs1. c1nc(C 2CCCCC2) cs1. c1nc(C 2CCCCC2) cs1. c1nc(C 2CCCCCC2) cs1. c1nc(C2 CCCO2) cs1. c1nc(C 2CCCCCC2) cs1. c1nc(C
#
#
# C=N N=C1 NC(=O)CS c1nc2ccccc2s1.CC1 ( CCCN2 CCC( c3ns c4cc(F)ccc34) CC2) NC(=O)NC1=O.O=C(O)C(F)(F)F.[C-]#[N+] c1ccc( [N+]2 =CCC( N=C3 NC(=O) CC3 =C) C=C2 C)cc1.[Na+].c1ccncc1. c1nc[nH] n1.c1ccc( CCCC 2CCCCC2)cc1. c1coc(C 2CCCC [NH2+] 2)c1. c1csc(- c2n[nH]c(C 3CCCC [NH2+] 3) n2)c1. c1csc(- c2n[nH]c(- c3ccco3) n2)c1. c1cncc(- c2n[nH]c(-
#
#
# C(=O)C(C) =C1O.Cl c1ccccc1.Oc1ccccc1.Oc1ccccc1.Oc1ccccc1.Oc1ccccc1 C=N CCN=C c1ccccc1O.[Co].[O H3+].[O H3+].[O H3+].[O H3+].[O H3+].[O H3+].[O H3+].[O H3+].[O H3+].[O H3+].[O H3+].[W ].[W].[W ]. c1ccccc1.c1ccccc1. c1ccccc1.c1ccc(-c2ccccc2)cc1.c1ccccc1.c1ccc(-c2ccccc2)cc1.c1ccc(-c2ccccc2)cc1.c1ccc(-c2ccccc2)cc1.c1ccc(-c2ccccc2)cc1.c1ccc(-c2ccccc2)cc1.c1ccc(-c2ccccc2)cc1.c1ccc(-c2ccccc2)cc1
#
#
# CCS(=O)(=O) c1ccc(C)cc1 O CCCC(=O) OC(C)(C)C.CCO C(=O)N1CCC( CCCC N2C(=O)c3ccccc3C2=O) CC1.CCO C(=O)N1CCC( CCCCC( CCN2C(=O)c3ccccc3C2=O) C(=O)O)CC1.CCO C(=O)N1CCC( CCCN) CC1.CCO C(=O)N1CCC( CCCN2 CCC[C@H]2 C(=O)OC) CC1.CCO C(=O)N1CCC( CCCC N2C(=O)c3ccccc3C2=O) CC1.Cl.O= CCc1ccccc1 Cl.[B]=NS.[H-].[Na+].[Ti].c1ccc(P (c2ccccc2) c2cccs2)cc1.c1ccc(P (c2ccccc2) c2cccs2)cc1.c1ccc(P (c2ccccc2) c2cccs2)cc1.c1ccc(P (c2ccccc2) c2cccc n2)cc1.
#
#
# C(=O)NC(C) c1ccccc1.CC1 (C(=O)N C( CCCO) c2ccc(F)cc2) CCCN1 C(=O)OCc1ccccc1.CC1 (C(=O)O) CCCN1 C(=O)OCc1ccccc1.CC1 (C(=O)O) CCCN1C(=O) CNC(=O)O c1ccccc1.CC1 (C(=O)OC c2ccc([N+](=O)[O-])cc2) CCCN1C(=O) CN C(=O)OCC1c2ccccc2-c2ccccc21.CCOC(=O)C1 CCCN1C(=O) CNC(=O)O c1ccccc1. O=[N+]([O-]) CC(O) /C=C/c1ccccc1.[B] B([B]) B(B([B])[B]) B([B])[B].c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1cc
(C)C)NC(=O) C(C)(C)NC(=O) OCC2c3ccccc3-c3ccccc32) c(C)c1.[2H] C(=O)OC c1ccc( CC(CO) NC(=O) CN2C(=O) C=CC2=O)cc1.[2H] [2H].[HH].[Na+].[OH-]. c1ccccc1.c1ccccc1 c1ccccc1.c1ccccc1. c1ccccc1.c1ccccc1 c1ccccc1.c1ccc(-c2ccccc2)cc1.c1ccc2c(c1)
#
#
# C(=O)CN =C1 NC # CCC2 =C(C = CC(C)(O) C=C2) N1.[HH].[ H] CCC.[HH].[HH].[ H] CCC.[C H] CCC.[ H] CCC.[C H] CCC.[CH2]CCC.[C H] CCC.[C H] CCC.[C H] CCC.[Sn].[Sn].[Sn].[Sn].[Sn].[Sn].[Sn].[Sn].[Sn].[Sn].[Sn].[Sn]
#
#
# CC(C(=O)O) CN1 C(=O)OCC1c2ccccc2-c2ccccc21. CC(C)(C)OC(=O)NC1 CC(=O) CC1C(=O)O N1C(=O)CCC1=O.CC1 CC(C(=O)O) CC2 CC(=O) CCC21.CC1 CC(C=O) CC2 CC(=O) CCC12.CC1 CC(C=O) CC2 CC(=O) CCC12.CC1 CC2C3 CC(CC 2C(=O) OC1=O) C(=O)OC3 =O.CC1 CC2 CC1CC2 1 C= CC(O)C1.CC1 CC2 CC1CC2 =O.CC1 CCC2CCCC (C1) C2CO. CCC1(C) CC2 CC1C1C3 CC(C(=O)O)
#
#
# CCC(=O) CC1C.CC.CC(C)C.CC(C) CC=O.CCCC C/C=C\ C1CC1 C(=O)C1 OC1 CC. CCCCCCC1 CC1 C(=O) CC1CC (C(=O)OC) C1(C)C.CCCCCC1 CC1 C(=O)C1 OC1 C. CCCCCCC(C) C1CC1 C(=O)O.CCCCCCCC CCC1CC1 C(=O)O. CCCCCC1 CC1CC1 CC1 C(=O)O. CCCCCC1 CC1CC1 CC1 C(=O)O. CCCCCC1 CC1CC1 CC1 C(=O)O. CCCCCC1 CC2 C=CC1 C(O) C2=O.CCCCCC1 CC1CC1 CC1
#
#
# S(=O)(=O)c1ccccc1 Br.CN1 CCC S1(=O)=O.CN1 CCC [S+]1[O-].CN1 CCS S1(=O)=O.Cc1ccccc1 S(=O)(=O)N1 CCN S1(=O)=O.C c1co c(C2 CCC2)n1.C c1co c(C2 CCC2)n1.C c1co c(C2 CCC2)n1.C c1co c(C2 CCC2)n1.O=[N+]([O-]) c1cc(Br)ccc1F.O=[N+]([O-]) c1cc(Br)ccc1F.O=[N+]([O-]) c1cc(Br)ccc1 S c1ccccc1Cl.[C-]#[N+] c1ccc(F)c(Br)c1.[C-]#[N+] c1ccc(F)c(Br)c1.[C-]#[N+] c1ccc(F)c(Br)c1.[C-]#[N+] c1ccc(F)c(Br)c1.[C-]#[N+] c1ccc(F)c(Br)c1
#
#
# C=N c2ccccc2S1.O=C(O)C(=O)O.[Pt]. c1csc(- c2ccc(-c3ccc(- c4nc5ccccc5s4) s3) s2)c1. c1csc(- c2ccc(-c3ccc(- c4nc5ccccc5s4) s3) s2)c1. c1csc(- c2ccc(-c3ccc(- c4nc5ccccc5s4) s3) s2)c1. c1csc(- c2ccc(-c3ccc(- c4nc5ccccc5s4) s3) s2)c1. c1csc(- c2ccc(-c3ccc(- c4nc5ccccc5s4) s3) s2)c1. c1csc(- c2ccc(-c3ccc(- c4nc5ccccc5s4) s 3)cc2)c1. c1csc(- c2ccc(-c3ccc(C 4CCCCC4) s3) s2)c1. c1csc(- c2ccc(-c3ccc(-
#
#
# C(=O)NC(C) C(=O)N1CCCC (C(=O)N c2ccc(Cl) c(F)c2)C1.CC(C) NC(=O)C1 C(=O)NCC1 C(=O)N1CCCC1 C(=O)N c1ccc(Cl)c(Cl)c1.CC(C) NC(=O)C1 COCC1 NC(=O) c1coc(C N2C(=O) CS C2=O) n1. CCC(CC) NC(=O)C1 CCC(=O)N1 Cc1cccc(C(=O)N c2ccc(Cl) nc2)c1.CCCC1 (C(=O)N c2ccc(Cl)cc2) CCCN1C(=O) C(C) NC(=O)OC(C)(C)C.CCCCC1 (C(=O)N c2ccc(Cl)cc2) CCCN1C(=O) C(NC(=O) OC)C1 (CC) CCCN1 C(=O)O. CCOC(=O)C1 (CC(C)C) CCCN1C(=O) C(NC(=O) OC)C1 CCCN1 C(C)=O.
#
#
# C(=O)NCC c1cn oc1 C(C)(C)C.CCC.CO.[HH].[Ti].c1ccc2c(c1) [cH-] c1ccccc12.c1ccc2c(c1) [cH-] c1ccccc12.c1ccc2c(c1) [cH-] c1ccccc12.c1ccc2c(c1) [cH-] c1ccccc12.c1ccc2c(c1) [cH-] c1ccccc12.c1ccc2c(c1) [cH-] c1ccccc12.c1ccc2c(c1) [cH-] c1ccccc12.c1ccc2c(c1) [cH-] c1ccccc12.c1ccc2c(c1) [cH-] c1ccccc12.c1ccc2c(c1) [cH-] c1ccccc12.c1ccc2c(c1) [cH-] c1ccccc12.c1ccc2c(c1) [cH-] c1ccccc12.c1ccc2c(c1) [cH-] c1ccccc12.c1ccc2c(c1) [cH-]
#
#
# CC(=O)OC N1 C=CC =C(C(N)=O) C1 C(F)(F)F.CCC(CC) OC(=O) CC1=N C=C(C)C1 C(F)(F)F. CCOC(=O)C1=C(C N2CCOCC2 C(=O)N C2CC2) N=C(C)C (C(=O)O CC2CC2) [C@@H]1 C. CCOC(=O)C1=C(C N2CCOCC2) NC(c2nccs2)=NC1 c1ccc(F)cc1Br.CCOC(=O) CC(C)=O.CN1 CCN=C1 CC(=O)OCC [Si](C)(C)C.Cn1cc (C(=O)O) c(- c2cc(F)ccc2 Br)n1.Cn1cc (C2 (C) CC(=O)OC N2 C(=O)OCc2ccccc2)cc1 CC(=O)O.Cn1 cc( CC(=O)OC N2 CCC(NC(=O) c3cc(- c4cc5
#
#
# C(=O)C(C) =C( OC(=O) c2cccnc2) C1C.CC C(=O)Oc1ccccc1 /C=C1\ SC(=S)N( [C@H](C) C(=O)O)C1=O.CC C(=O)O[C@H](C [C@H](C(C)C)N(C)C(=O) [C@@H](CC(=O) [C@H]1CCCCN1C) [C@@H](C)CC) c1nc(C(=O)N [C@@H](C c2ncc(C) cn2) CC(C)C) cs1.CC C(=O)O[C@H](C [C@H](C(C)C)N(C)C(=O) [C@@H](CC(=O) [C@H]1CCCCN1C) [C@@H](C)CC) c1nc(C(=O)N [C@@H](C c2ncccn2) CC(C)C) cs1. COc1cccc(CC (C)C NC(=O) [C@@H](C)C(=O) [C@@H](C(C)C) N(C)C) c1. COc1cccc(CC (C)C NC(=O) [C@@H](C)C(=O) [C@H](C(C)C) N(C)C) c1.
#
#
# CCC(C)=O.CCCC (CC) CC(C) CCN1C(=O) CC(C) C1=O.CCCC (CC) CC(C) CCN1C(=O) CC(C) C1=O.CCCC C(C) CCCCC(CC) CCN1C(=O) CC(C) C1=O.CCCC C(C) CCCCC(CC) CCN1C(=O) CC(C) C1=O. CN1C(=O) CC(O) C1=O.CNC(=O) C(CCC(=O)O) N1C(=O)C=CC1=O.O=C(O) CCCN1C(=O) C=CC1=O.O=C=O.O=CO CCCCCN1C(=O) CCC1=O.[2H]CF.[Na+].[OH-]. c1cc[nH]c1. c1ccc2[nH] cnc2c1. c1ccc2[nH]ccc2c1. c1ccc2[nH]ncc2
#
#
# CCC(=O)O C( CC(C(C)C) N(C)C(=O) [C@@H](NC(=O) C(C(C)C) N(C)C) C(C)CC) C(C) CC1C.CC(C) C(NC(=O) C(CCCCNC(=O) O) NC(=O)C( CC(C)(C)C) N(C)C(=O) C(CCCCNC(=O) OC c1cncs1) NC(=O)C( CC(=O)N1CCCC1) C(C)(C) c1ccccc1) C(N)=O.CC1(C) CCC(=O)N1 Cc1ccccc1.CC1 (C)C2 CCC1(C) C(O C(=O)N(CCCC CC(=O)O) CC(=O)N C(CC(=O)O) C(=O)O) C2.CCC.NC(=O) CC(NC(=O) C(CCCCNC(=O) OC c1cncs1) NC(=O)C(C c1ccc(O)cc1) NC(=O)C1CCCN1) C(=O)O.[Li+].[OH-]
#
#
# C(=O)N1CCOCC1 C(=O)O CCCc1ccccc1.CCCC OC(=O) CCCN1C(=O) C=CC1 =O. CCOC(=O)C1=C(C OCCN) NC(C) =C(C(=O)OC) C1c1ccccc1 Cl. CCOC(=O)C1=C(C OCCNC(=O) c2cccnc2) NC(C) =C(C(=O)OC) C1c1ccccc1 Cl. CCOC(=O)C1=C(C OCCNC(=O) c2cccnc2) NC(C) =C(C(=O)OC)C1 c1ccccc1Cl.CO C(=O)N1CCN(C(=O) CO CCCC(=O)O) C(C)C1 c1ccccc1 Cl. FC1(F) CCCCC1.[Li+].[OH-]. OC[C@@H]1 CCCCN1.[C-]#[N+] C1 (C(F)F) CCCN(C(=O) CO CCCN) C1 c1ccccc1Cl.[C-]#[N+]
#
#
# C(=O)NCC c1c[nH]c2ccccc12.CC C(=O)OC1 CCCc2ccccc21.CCO C(=O)N1CCC( CC(=O) c2ccc3c(c2) /C(=C/ c2[nH] c(C)cc2 C) C(=O)N 3)CC1. CCOC(=O)C1=C c2cc(O)ccc2 C1. CCOC(=O)C1 CC(=O) CCC1 =O. CCOC(=O)C1 CC2(CC C( CC(=O)OCC) CC2 N)C1.CCOC(=O) CCC(=O) c1ccc2c(c1) /C(=C/ c1[nH] c(C)cc1 C) C(=O)N2.CCOC(=O) CCC(=O) c1ccc2c(c1) /C(=C/ c1[nH] c(C)cc1 C) C(=O)N2.CCOC(=O) CCc1ccc2c(c1) /C(=C/ c1[nH]
#
#
# C(=O)CN (CC) C1=O.COC. COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O) CC(C(=O) C(C)C O) C[C@@H]3O.[2H]CF.[H-].[Na+]. c1ccccc1.c1ccccc1 c1ccccc1.c1ccc(-c2ccccc2)cc1.c1ccccc1. c1ccc(-n2ccnc2)cc1. c1ccc2[nH] ccc2c1. c1ccsc1. c1ccsc1. c1cscn1. c1nc[nH] n1. c1n cs n1. c1nn co1. c1ns cn1. c1nn[nH]n1. c1nncs1. c1nn[nH]n1. c1nncs1. c1nncs1.
#
#
# CC(N)=S.CCOC(=O) C(C) N1C(=O) CO c2ccc(-c3cs c(-c4ccccc4) n3)cc21.CCOC(=O) C(CC(C)C) N1C(=O) CO c2ccc(N C(=S) NC(=O)CO c3ccccc3)cc21.N C(=S) Oc1ccc2c(c1) OCC(=O)N2.O=C (Cl)Cl.O=C(O) CS c1nc2ccccc2s1.S =C (Cl)Cl.[3H] CS c1nc2ccccc2s1.[C-]#[N+] CC(=O) CCCO c1ccc(OC)cc1.[C-]#[N+] CC(=O) CCCO c1ccc(OC)cc1.[C-]#[N+] CC(=O)N C(=S)NC c1ccc2c(c1)OCO2.[C-]#[N+] CC(=O)OCC.[C-]#[N+] CC(=O)OCC.[Cl-].[Cl-].[Li+]
#
#
# C(=O)NCC c1c[nH]c2ccccc12.CC(C)C n1 c(C(=O)O) c(C (c2ccccc2)c2ccccc2) c2ccccc21.CCCC OC(=O) c1cn(C c2ccc(OC)cc2) c2ccccc12.COc1ccccc1 OC(=O) c1cn(C c2ccccc2OC) c2ccccc12.COc1ccccc1 OC(=O) c1cn(C c2ccccc2OC) c2ccccc12.COc1ccccc1 OC(=O) c1cn(C c2ccccc2OC) c2ccccc12.COc1ccccc1 OC(=O) c1cn(C c2ccccc2Cl) c2ccccc12.O=C( OC(=O) c1cn(Cc2ccccc2) c2ccc(F)cc1 2)c1ccccc1.O=C=O.O=C=O.O=C=O.O=C=O.O=C=O.O=C=O.O=C=O.O=C c1cnc[nH]1.[C-]#[N+] C1 (Cc2ccccc2) C(=O) C(CCc2ccccc2) (C(C)C)
#
#
# C(=O)OCc1ccccc1.CC c1cccc(C)c1 N(C OC)C(=O) CCl.CC c1cccc(C)c1 N(C OC)C(=O) CCl.N O.[Pd].c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1. c1ccsc1. c1ccsc1. c1ccsc1.[Cl-].[Cl-].[Pd ].[Pd ].c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1ccc( [Si] (c2ccccc2)c2ccccc2)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1. c1ccsc1.c1ccncc1. c1ccsc1. c1ccsc1. c1cn[nH] c1. c1nc[nH] n1. c1co cn1. c1nc[nH] n1.
#
#
# CC(=O)OC (C (C(F)(F)F)C(F)(F)F) (C(F)(F)F) NC1=O. CCCC(=O)OC (C(=O) OC1C [C@@]2(O) [C@@H](OC(=O)c3ccccc3) [C@@H]3 [C@]4 (OC(C)=O) CO[C@@H]4 C[C@H](C) [C@@]3(C)C(=O) [C@H](OC(C)=O) C(=C1C) C2(C)C) C(C) CC.CCC(C) (F) C(=O)OC1 (CC) C2CC3CC(C2)CC1C3.CCC(C) (F) C(=O)OC1 C(=O)OC2 OC3 COC(=O) c4cc(O) c(O)c(O) c4- c4c( cc(O)c(O) c4O) C(=O)OC3 (C)C2 1. CCCC(C) C(=O)OC1 C(=O)OC2 OC3 C(OC(=O) C(C)(C)CC) COC
#
#
# CC(=O)OCC # CC(C)(C)C OC(=O)C1 CC(=O)N (CCC (C)C)C1 c1ccc(OC)cc1 O.O=C1 CC(C(=O) S CC/C=C/ C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 /C=C/ C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2 C2CC2
#
#
# CC(N) c2ccccc21.O=C NC1CC1 c1ccccc1.O= CC1CCCC1 c1ccccc1.O= CC1CCCC1 c1ccccc1Cl.[HH].[HH].[V].c1ccc2c(c1) CCC2.c1ccc2c(c1) CCCC2. c1ccc2c(c1)OCO2.c1ccc2 c(C3CCCCC3) c[nH]c2c1.c1ccc2 c(C3CCCCC3) c[nH]c2c1.c1cn c2[nH]ccc2c1.c1cn c2[nH]ccc2c1.c1cn c2[nH]ncc2 c1. c1ncc2c(n1) CCC2. c1nc2c(s1)CCCC2. c1nc2c(s1)CCCC2. c1nc2c(s1) C(=O)CCC2. c1nc2c(s1)CCCC2.c1ccc2c(c1) CCCC2. c1nc(C2CC2) cs1.
#
#
# CC(=O)OC (C (Cl)(Cl)Cl) N1 C(C)=O.CC(=O) OC(C)=O.CC(=O)O CC1 c2ccccc2-c2ccccc21.CO.COC(=O) CC1 (C(=O)OC) Cc2ccccc2 C1=O. COC(=O)C1 (C) NC c2ccccc21.COC(=O) C(N) C(=O)OC.COC(=O)C1 C c2c(Cl)cccc2 C1=O. COC(=O)C1 N c2ccccc2C1=O.COC(=O)C1 NC c2ccccc21.II.O=C1 Cc2ccccc2N1.O=C1 c2ccccc2 CN1 C1 CN2CCC1CC2.O=C1OC(=O) c2cc(Cl)ccc21.O=C1 Nc2ccccc2 C1O.O=C=O.O=C=O.O=C=O.O=C=O.O=C=O.O=C=O.[H-].[Na+]
#
#
# C(=O)Nc1ccccc1 Br.O=C1 C( c2c(O)[nH] c3cc(Cl) ccc23) =Nc2ccccc21.O=c1[nH] [nH] c2cc(Cl)ccc12. c1cc2cc( c1) -n1 ccc3 cc( ccc31) Nc1n ccc( n1) Oc1ccc( cc1) CC c1ccc -2 cc1.c1ccc(C 2C c3c[nH] cc3- c3cc(N 4CCCC4) c4[nH] cn c4c32)cc1. c1cc2cc( c1)C1 c3cn cc4c3 C( c3ccc(N 5CCOCC5)cc4 - c4cc nc5 cn2 cc45)
#
#
# CC(N)=S.CCOC =C(C(=O)OCC) C(N)=S.CCOC =C(C(=O)OCC) C(N)=S.N C(N)=S.O=C OC c1ccc([N+](=O)[O-])cc1.O=C OC c1ccc([N+](=O)[O-])cc1.O=C OC c1ccc([N+](=O)[O-])cc1.O=C OC c1ccc([N+](=O)[O-])cc1.O=C OC c1ccc([N+](=O)[O-])cc1.O=C OC c1ccc([N+](=O)[O-])cc1.O=C OC c1ccc([N+](=O)[O-])cc1.O=C OC c1ccc([N+](=O)[O-])cc1.O=C OC c1ccc([N+](=O)[O-])cc1.O=C OC c1cccc([N+](=O)[O-])c1.O=C OC c1cccc([N+](=O)[O-])c1.O=C OC c1cccc([N+](=O)[O-])c1.O=C OCc1ccccc1.O=C OC
#
#
# C(=O)C(C) =C1C.CC OC(C) OC(C) OCC.O=C=O.O= c1n (CCO) c(=O)n (CO) c(=O)n1 CCl.OCC n1nn c(CO) n1.[2H] CC.[2H] CC.[3H] CCN.[3H] CCn1 nnnc1 CO.[3H] n1 nnnc1 COC.[W ].[W +2].[W ] = [OH+]. c1ccccc1.c1ccccc1. c1ccccc1.c1ccc2c(c1) nnn2 CO n1nn c2cccnc21.c1cn c2nnn [n-]
#
#
# C(=O)NC /C=C/C(C)=C/ C1 CCCCC c2c1n nn2 O.CCC.CO.N.[HH].[HH].[Ti].c1ccc2c(c1) C1CCC2 C2 CCCCC12.c1ccc2c(c1) C1CCC2 C2CCCN C21.c1ccc2c(c1) C1CCC2 C2 CCCCC12. c1ccc2c3c(ccc2c1) OC1 CCCC3 1. c1ccc2c3c(ccc2c1) SC1 CCCC3 1. c1ccc2c3c(ccc2c1) SC1 CCCC3 1.c1ccc2c(c1) C1 c3ccccc3C2 c2ccccc21.c1ccc2c(c1) C1CC c3ccccc3C1 N2C c1ccc2c(c1)OCO2.c1ccc2c(c1)
#
#
# C(=O)NC(C) c1ccccc1.O=C1 CC(c2ccccc2) C(=O)O1.O=C1 CCC(c2ccccc2) N1c1ccccc1.O=C1 CN C(c2ccccc2)N1.O=C1 CN(Cc2ccccc2) C(c2ccccc2) C(=O)N1Cc1ccccc1.O=C1 c2ccccc2C(=O)N1 Cc1ccccc1.O=C1 c2ccccc2 C(=O)N1CCCC c1ccccc1. O=c1[nH]c2ccccc2 n1-c1ccccc1.O O.[Na+].[OH-].c1cc2 cccc3 c4cccc5cccc( c(c1) c23)c54. c1ccc(O CCCCCN c2c3ccccc3 nc3ccccc23)cc1. c1ccc2ccccc2c1 N( CCCN c1c2ccccc2 nc2ccccc12) c1cccc2ccccc12.c1ccc2 cc3ccccc3 c(N CCCN3 c4cccc5cccc(
#
#
# CC(N)=S.Cl.O C(CCl) CCCCl.[2H] [B].[N-]=[N+]=N CC(=O)N (CCO)CCO.[N-]=[N+]=[N-].[Na+].[O-2].[O-][Cl+3]([O-])([O-])[O-].[S e +4].[S e -2].[S e -2].[S e -2].[S e -2].[S e -2].[S e -2].[S e -2].[S e -2].[ Ti +4].[ Ti +4].[ Ti +4].[ Ti +4].[
#
#
# CC(=O)O C1CCC1 CCOC1 CC C(F)F.CO CCOCCO CCOC1 CCCCO1.O=C( CC1 CCO1) C1CCC1 CCO.O=C( CC1 CCO1) C1CCC1 CCOCc1ccccc1.O=C( CC1CO C1) C1CCC1.OCC C(F)(F)F.O CC1CCC( CC2CC2)CC1.O CC1CCC( CC2CC2)CC1.OC1 CCC( CC2CC2)CC1.OCCO CC1CCCCC1.OCCO CC1CCCCC1. OCC(F)(F) C1CCC1.OC OC1CCCC1.OC c1ccc(F)cc1. c1cc(N 2CCCCC2 )ccn1
#
#
# CC(=O)OC (Cc2ccccc2) CC=CC =CC( CC(=O)N CCOCCO) C(=O)N1.CC1 CCCC1 CC(=O)O.CC1 CCCC1 CC(=O)O.CC(N) CCNC(=O) OCc1ccccc1.C c1cccc(O)c1 C=O.C c1cccc(O)c1 C=O.O=C(O) CC1CCC =CC=C1 OCc1ccccc1.O=C=O.O=C=O.O=C(O) CC1 C=CC(O) C=C1 OCc1ccccc1.O=C(O) CC1 C=CCC1 O.O=C1 NC c2cccc(c2) OC/C=C/ CO c2cccc(c2) NC(=O)CO c2ccc(cc2) CC(C(=O)O) NC(=O)C1 O.O c1cccc(N O)c1
#
#
# CC(=O)O C1O c1ccccc1 CCO [N+](=O)[O-].CC c1c2c(n c3ccc(O) c(C =NC c4ccc(OC)cc4) c13) - c1cc3c(c(=O)n1C2)COC(=O) C3(O) CC.CC c1c2c(n c3ccc(O C(=O)N4 CCC(N 5CCCCC5) CC4)cc1 3)-c1cc3c(c(=O)n1C2)COC(=O) C3(O) CC.[3H] OC.[Y].c1ccc(- c2ccnc3 c2ccc2 c(-c4ccccc4 )cc nc23)cc1.c1ccc(- c2ccnc3 c2ccc2 c(-c4ccccc4 )cc nc23)cc1.c1ccc(- c2ccnc3 c2ccc2 c(-c4ccccc4 )cc nc23)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1cn c2ncccc2c1
#
#
# CC(C(=O)O) NC1 c1ccccc1 CC c1ccc(Br)cc1.Cl.O=C(O)c1ccccc1 CCc1ccc(F)cc1.O=C(O) C1CC C(=O)N1 c1ccccc1Br.O=C(O) C1 NCC C(=O)N1 c1ccccc1C(F)(F)F.[Li+].[OH-]. OC1( c2cccc(F)c2F) CC c2nc[nH] c2C1.O= c1cc[nH] c(C2 (C(=O)O)CC(O) C2 c2cccc(F)c2)c1.O=C c1cccc(F)c1.[B ].[B] [B] B(B([B])[B]) B(B([B])[B]) B(B(B(B([B])[B])B([B])[B])B(B([B])[B])B([B])[B]) B( B(B(B(B([B])[B])B([B])[B])B(B([B])[B])B([B])[B]) B(B(B([B])[B])B([B])[B])B(B([B])[B])B([B])[B]) B( B(B(B(B([B])[B])B([B])[B])B(B([B])[B])B([B])[B]) B(B(B([B])[B])B([B])[B])B(B([B])[B])B([B])[B]) B(B(B(B([B])[B])B([B])[B])B(B([B])[B])B([B])[B]) B(B(B([B])[B])B([B])[B]) B(B([B])[B]) B([B])[B].
#
#
# CC(=O)O C1(C)C c1ccccc1.CC(C)C (C(=O)O)C1 CC(=O)O C1(C)C c1ccccc1.CC(C)C (C)C(=O)O.CC(C)C (C(=O)O CC(C)(C)C) C1C(=O)O C1(C)C c1ccccc1.CC(C)C (C(=O)OC(C)(C)C) C1 CC(=O)O C1(C)C c1ccccc1.CC1 =C(C(C)C) C(=O)OC1 C(C)(C)C.CCC1 OC (C(C)(C)C) C(C(=O) C(C)(C)C) C1C.O CC1CCCCC1.O CC1CCCCC1.O CC1CCCCC1.O CC1CCCCC1.O CC1CCCCC1.O CC1CCCCC1.O CC1CCCCC1.O CC1CCCCC1.[CH
#
#
# CCS(=O)(=O) C12 CN(C)C2 =O.CC(=O) c1ccccc1 C1 CCS(=O)(=O) C12 CCN(C)CC2.CC(=O) c1ccccc1 C1 CCS(=O)(=O) C12 CCN(C)CC2.CC1 ( c2ccccc2C(=O)O) CCS(=O)(=O) C12 CCN(C)CC2 =O. Cc1cc(- c2ccccc2C(=O)O) ccc1- n1cnnn1.Cc1cc(- c2ccccc2C(=O)O) ccc1 NS(=O)(=O)c1ccccc1.O=C=O.O=C=O.O=C=O.O=CO /C=C/ c1ccccc1- c1nn[nH]n1.O=C=O.O=CO /C=C/ c1ccccc1- c1nn[nH]n1.O=C=O.O=S(=O) (C1 =N CCO1) N1CCC1.O=S(=O)(
#
#
# C(=O)N1CCCCC1 CCO.CC (N)=O.CCCC C(C) C(N)=O.CO.NC=O.O=CO.O=C NCCCC (NC(=O) CCC(=O)O) C(=O)COc1ccccc1.O=C NC( CCC(=O)N C(CCCC OCc1ccccc1) C(=O)NC c1ccccc1)C(=O)O CCc1ccccc1.O=C NC(C(=O)O) c1ccccc1.O=C NC=O.O=C NC c1cccc2ccccc12.O=C NC(C c1cccs1) C(=O)N[C@@H](C c1cccnc1) C(=O)N[C@@H](CC1CCCCC1) C(=O)O CCc1ccccc1.O=C NC(C(=O)N C(CCc1ccccc1) C(=O)NCC c1c[nH]c2ccccc12) c1ccccc1.O=C NC(C(=O)O) c1ccccc1.O=C
#
#
# C(=O)Cl.CO CCN(C(=O) N1 C(C) CCC1 C(=O)O)C1 CCSC1.O CC1 CCSC1.[O-][S+](Cl)Cl.[Ti]. c1cc(C2 CS CCS 2)cs1. c1cc(C2 CSCCN 2)cs1. c1cc(CO c2ccc(OCC3 CCS CC3 c3cc [nH] c3)cc2) cs1. c1cc(C SCC2 CCCS 2)cs1. c1ccc(CN CC2 CCS C2)nc1. c1ccc(CN2 CCS C2) nc1. c1ccc(CO c2ccc(CC3
#
#
# C(=O)NC(C) c1cccc(C(F)(F)F)c1 F.CC c1cccc(CC)c1 NC(=O)N (CC) c1c(Cl)ccc (C)c1 F.O=C(N c1ccccc1Cl) N1CC C(F)( c2cccc(Cl) n2) C(F) C1. O=C(N c1ccccc1Cl) N1CC C(F)( c2cccc(Cl) n2)CC1.O=C(N c1ccccc1Cl) N1CC C(F)( c2cccc(Cl) n2)CC1.O=C(N c1ccccc1Cl) N1CC C(F)( c2cccc(Cl) n2)CC1.O=C(N c1ccccc1Cl) N1CC C(F)( c2cccc(Cl) n2)CC1.O=C(N c1ccccc1Cl) N1CC C(F)( c2cccc(Cl) n2)CC1.O=C(N
#
#
# C=N C( N2CCC( CC(=O)O) CC2) =NC1 Cl.COC =O.CO CCN C=O. COc1cc(C)cc (OC)c1 C(C) CCN1 CCC(C2 CCN( c3ccc(C(N)=O) c4[nH] c5cc (C(C)(C)O) ccc5 c34) CC2)CC1.Cl c1ccccc1 OC1 CNC1.O=C(O) C1= CCNCC1.OC1 CCNC1.[C-]#[N+] c1ccc(OC2 C(C)(C) C(N) C2(C)C)cc1.[C-]#[N+] c1ccc(OC2 C(C)(C) C(NC(=O) c3ccc(C4 CC(N 5CC C(F)(F) CC5)
#
#
# C(=O)NCC c1ccc(Cl)cc1.O=C N c1ccc(OC(F)(F)F)cc1.O=C Nc1n c2ccc(OC(F)(F)F)cc2 s1.O=C(N CC c1ccc(Cl)cc1) C1 CCCCN1C(=O) CC c1ccc(Cl)cc1F.O=C(N CC c1ccc(Cl)cc1) C1 CCCCN1C(=O) Cc1ccc2ccccc2c1 C(F)(F)F.O=C(N CC c1ccc(Cl)cc1) C1 CCCCN1C(=O) CCC c1ccc(F)cc1F.O=C(N CC c1ccc(F)cc1) C1 CCCCN1C(=O) CCC c1ccc(F)cc1F.O=C(N CC c1ccc(F)cc1)c1ccccc1 C(=O)c1ccccc1 Cl. O=C(NC c1ccc(Cl)cc1) C1CCCN( CCC c2cccc(Cl)c2)C1.O=C(NC c1ccc(Cl)cc1)
#
#
# CCl.CC(C) CC1 CCCNC1=O.CC1(C) OCC (CC#N) O1. CCC1(C) OCC( CC(C)(C)O) O1.COC =O.COC =O.COC =O.COC (Cl) Cl. N#CC1 CCCO1.O=C1 CCCC CO1.O=C (Cl)Cl.[2H] CC.[2H]CF.[2H] CC.[2H] CC.[2H]CF.[2H]CF.[H-].[Na+].[Li+].[OH-].[N-]=[N+] =NC1 CCOC1=O.[Na+].[O H3+].[O H3+].[O H3+]
#
#
# C(=O)Cl.CC c1cccc(CC)c1 N(C(=O)CCl) C(C)COC.CC c1cccc(CC)c1 N(C OC)C(=O) Cl.N O.O =NN( [O-]) c1ccccc1.O=C( OCC l) c1ccccc1.O=C =Nc1ccccc1.[B ].[B].[NH -2 ].[V +2].[Na+].[OH-].[OH-].[OH-].[Z n+2].[ Zn+2].c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1.c1ccc(P(c2ccccc2)c2ccccc2)cc1. c1cc(C 2CCCCC2 )ccc1 NC1=N CCN1. c1cc(C 2CCCCC2 )ccc1 NC1=N CCN1. c1cc(C 2CCCCC2 )ccc1
#
#
# C(=O)NCC [C@H](O) [C@@H]1C c2cccc(O)c2 C(=O)O1.S I =S=S.S I.[3H] C.[C-]#[N+] c1ccc(N2C(=O) [C@H]3[C@H]( CCC(C) =C3 CC) N(CC (O)CO) C2=O)cc1.[C-]#[N+] c1ccc(N2C(=O) [C@H]3[C@H]( CCC(C) =C3 CC) N(CC (O)CO) C2=O)cc1.[C-]#[N+] c1ccc(N2C(=O) [C@H]3[C@H]( CCC(C) =C3 CC) N(CC (O)CO) C2=O)cc1.[C-]#[N+] c1ccc(N2C(=O) [C@H]3[C@H]( CCC(C) =C3 CC) N(CC (O)CO) C2=O)cc1.[C-]#[N+]
