# %%
import random
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors
from rdkit.Chem import rdmolops
import joblib
from tqdm.auto import tqdm
import pandas as pd


from src.utils import all_rools_valid, sa_score

# %%
estimation_model, feature_names = list(joblib.load('models/model_iter_2').values())

desc_dict = dict(Descriptors.descList)

descriptor_funcs = []
for f_name in feature_names:
    descriptor_funcs.append((f_name, desc_dict[f_name]))

# %%
initial_molecules = \
pd.read_csv('data/quantitive_neftekod25_data.csv')['SMILES'].drop_duplicates().tolist() +\
pd.read_csv('data/export.csv')['SMILES'].tolist()

# %%
initial_molecules[:10]
# Out:
# ['C1=CC=C(C=C1)NC2=CC=CC=C2',
#  'CC(C)(C)CC(C)(C)C1=CC=CC=C1NC2=CC=CC3=CC=CC=C32',
#  'C1(=CC=CC=C1N(C2=CC=CC=C2CCCCCCCCC)[H])CCCCCCCCC',
#  'C1=CC=C(C=C1)NC2=CC=CC3=CC=CC=C32',
#  'CC1=C(C(=CC=C1)O)C',
#  'CC1=CC(=C(C=C1)C)O',
#  'CC1=C(C=C(C=C1)O)C',
#  'CC1=CC(=CC(=C1)O)C',
#  'CCC1=CC=C(C=C1)O',
#  'CC1=CC(=C(C(=C1)C(C)(C)C)O)C(C)(C)C']

# %%
class GeneticAlgorithm:
    def __init__(self, mutation_func, crossover_func, fitness_func, population_size, mutation_prob, crossover_prob):

        self.mutation_func = mutation_func
        self.crossover_func = crossover_func
        self.fitness_func = fitness_func
        self.population_size = population_size
        self.mutation_prob = mutation_prob
        self.crossover_prob = crossover_prob
        self.log = []

    def run(self, initial_population, iterations):

        population = initial_population.copy()

        for _ in range(iterations):

            fitness_values = [self.fitness_func(ind) for ind in population]
            
            min_fitness = min(fitness_values)
            max_fitness = max(fitness_values)
            avg_fitness = sum(fitness_values) / len(fitness_values)
            sorted_fitness = sorted(fitness_values)
            median_fitness = sorted_fitness[len(sorted_fitness) // 2] if len(sorted_fitness) % 2 == 1 else (
                sorted_fitness[len(sorted_fitness) // 2 - 1] + sorted_fitness[len(sorted_fitness) // 2])/ 2
            
            self.log.append({
                'min': min_fitness,
                'max': max_fitness,
                'avg': avg_fitness,
                'median': median_fitness
            })

            print(self.log[-1])
            pd.DataFrame({'SMILES': population, 'res_fitness': fitness_values}).to_csv('gen_algo_cache/population_mol_based.csv', index=False)
            
            offspring = []
            for i in tqdm(range(min(len(population), self.population_size))):

                if random.random() < self.crossover_prob:
                    parent1 = self._tournament_selection(population, fitness_values)
                    parent2 = self._tournament_selection(population, fitness_values)
                    child1, child2 = self.crossover_func(parent1, parent2)
    
                    offspring.extend([child1, child2])
                

                if random.random() < self.mutation_prob:
                    mut_child = self.mutation_func(population[i])
                    offspring.append(mut_child)

            combined = population + offspring
            combined = list(set(combined))
            combined.sort(key=lambda x: -self.fitness_func(x))
            population = combined[:self.population_size]
        
        return population, self.log

    def _tournament_selection(self, population, fitness_values, tournament_size=3):
        participants = random.sample(list(zip(population, fitness_values)), tournament_size)
        participants.sort(key=lambda x: -x[1])
        return participants[0][0]

# %%
firness_cache = {}

groups = [
    'O',                 # -OH (гидроксил)
    'N',                 # -NH2 (аминогруппа)
    'OC(=O)C',           # Ацетилокси-группа
    'c1ccccc1',          # Бензольное кольцо
    'c1cc(-c2ccccc2)cc(-c2ccccc2)c1',  # Бифенильные структуры
    'c1ccc2c(c1)ccc1c2ccccc1',           # Нафталиновые ядра
    'C(C)(C)C',          # Трет-бутильная группа
    'C#C',               # Алкиновые группы
    'C=O',               # Карбонильная группа
    'NC(=O)',            # Амидная группа
    'S(=O)(=O)',         # Сульфоновая группа
    'CSC',               # Тиоэфир
    'COC(=O)',           # Сложноэфирная группа
    'C1CCCCC1',          # Циклогексильное кольцо
    'C(C)=C',            # Алкеновая группа
    'CN(C)C',            # Диметиламиногруппа
    'c1ccncc1',          # Пиридиновое кольцо
    'Oc1ccccc1',         # Феноксильная группа
    'C(C)(O)N',          # Аминоспиртовая группа
    'C1=CC=C(C=C1)O'     # Замещённое фенольное кольцо
]

def mol_based_mutation(smiles: str, max_attempts=100):

    mol = Chem.MolFromSmiles(smiles)
    
    def _add_group_to_bond(mol):
        if len(mol.GetBonds()) == 0:
            return mol
        bond = random.choice(mol.GetBonds())
        mol = Chem.RWMol(mol)
        mol.RemoveBond(bond.GetBeginAtomIdx(), bond.GetEndAtomIdx())
        
        group = random.choice(groups)
        group_mol = Chem.MolFromSmiles(group)
        mol.InsertMol(group_mol)

        return Chem.MolFromSmiles(Chem.MolToSmiles(mol))
    
    
    def _add_functional_group(mol):
        
        atom_idx = random.choice([a.GetIdx() for a in mol.GetAtoms()])
        
        rw_mol = Chem.RWMol(mol)
        
        new_group = Chem.MolFromSmiles(random.choice(groups))
        new_group_atoms = list(new_group.GetAtoms())
        
        combo = Chem.CombineMols(rw_mol, new_group)
        
        rw_mol.AddBond(
            atom_idx,
            rw_mol.GetNumAtoms() - 1,
            Chem.BondType.SINGLE
        )
        
        new_mol = rw_mol.GetMol()

        return Chem.MolFromSmiles(Chem.MolToSmiles(new_mol))
        
    transform = random.choice((_add_group_to_bond, _add_functional_group))

    for attempt in range(max_attempts):
        try:
            new_mol = transform(mol)
            new_smiles = Chem.MolToSmiles(new_mol)

            new_smiles = new_smiles.replace('.', '')
            
            assert all_rools_valid(new_smiles)
            return new_smiles
            
        except Exception as e:
            continue

    return smiles


def mol_based_crossover(smiles1: str, smiles2: str, max_attempts=100):

    def _get_breakable_bonds(mol):
        breakable = []
        for bond in mol.GetBonds():
            if bond.GetBondType() == Chem.BondType.SINGLE:
                if bond.GetBeginAtom().GetSymbol() in ['C','O','N'] and \
                   bond.GetEndAtom().GetSymbol() in ['C','O','N']:
                    breakable.append(bond.GetIdx())
        return breakable
    
    def _get_fragments(mol, bond_idx):

        broken = rdmolops.FragmentOnBonds(mol, [bond_idx], addDummies=True)
        return Chem.GetMolFrags(broken, asMols=True, sanitizeFrags=False)

    def crossover(mol1, mol2):        
        bond1 = random.choice(_get_breakable_bonds(mol1))
        bond2 = random.choice(_get_breakable_bonds(mol2))
        
        frags1 = rdmolops.FragmentOnBonds(mol1, [bond1])
        frags2 = rdmolops.FragmentOnBonds(mol2, [bond2])

        frags1 = _get_fragments(mol1, bond1)
        frags2 = _get_fragments(mol2, bond2)
        
        frag1 = random.choice(frags1)
        frag2 = random.choice(frags2)
        
        combined = Chem.CombineMols(frag1, frag2)
        editable = Chem.EditableMol(combined)
        
        dummies = [atom.GetIdx() for atom in combined.GetAtoms() if atom.GetAtomicNum() == 0]

        if len(dummies) >= 2:
            editable.AddBond(dummies[-2], dummies[-1], Chem.BondType.SINGLE)
            editable.RemoveAtom(dummies[-1])
            editable.RemoveAtom(dummies[-2])


        tmp_mol = editable.GetMol()

        for atom in reversed(list(tmp_mol.GetAtoms())):
            if atom.GetAtomicNum() == 0:
                editable.RemoveAtom(atom.GetIdx())

        new_mol = editable.GetMol()
        
        return editable.GetMol()

    mol1 = Chem.MolFromSmiles(smiles1)
    mol2 = Chem.MolFromSmiles(smiles2)

    for attempt in range(max_attempts):
        
        try:
            new_mol = crossover(mol1, mol2)
            new_smiles = Chem.MolToSmiles(new_mol)
            
            new_smiles = new_smiles.replace('.', '')
            
            assert all_rools_valid(new_smiles)
            return new_smiles, new_smiles
            
        except Exception as e:
            continue

    return smiles1, smiles2


def calculate_fitness(smiles: str) -> float:

    if smiles in firness_cache:
        return firness_cache[smiles]
    
    mol = Chem.MolFromSmiles(smiles)
    descriptors = {desc_name: desc_f(mol) for desc_name, desc_f in descriptor_funcs}
    X = pd.DataFrame([descriptors])
    prediction = estimation_model.predict(X)[0]

    raw_sa = sa_score(smiles)

    penalty = (raw_sa - 3) ** 4

    res = prediction - penalty 
    
    firness_cache[smiles] = res
    
    return res

# %%
from rdkit import rdBase

rdBase.DisableLog('rdApp.error')  
rdBase.DisableLog('rdApp.warning')

# %%
mol_based_genetic_algo = GeneticAlgorithm(
    mol_based_mutation,
    mol_based_crossover,
    calculate_fitness,
    population_size=200,
    mutation_prob=0.8,
    crossover_prob=0.8
)

_ = mol_based_genetic_algo.run(initial_molecules, 10)
# Out:
# {'min': -18.627716952186717, 'max': 341.82751146461203, 'avg': 155.0205943069376, 'median': 192.30471646230126}
# 100%|██████████| 85/85 [00:02<00:00, 33.75it/s]
# {'min': 0.32924627539441076, 'max': 372.00136281639135, 'avg': 193.75069924046727, 'median': 233.03262860226732}
# 100%|██████████| 200/200 [00:05<00:00, 36.35it/s]
# {'min': 260.70775889861363, 'max': 417.29783382444884, 'avg': 306.33300754621405, 'median': 303.63735628202573}
# 100%|██████████| 200/200 [00:07<00:00, 27.96it/s]
# {'min': 314.0653048449017, 'max': 417.29783382444884, 'avg': 340.5848931659966, 'median': 335.2604619448733}
# 100%|██████████| 200/200 [00:10<00:00, 18.42it/s]
# {'min': 340.5805255776993, 'max': 437.25360514841145, 'avg': 364.2421495210327, 'median': 358.9107081943385}
# 100%|██████████| 200/200 [00:12<00:00, 15.59it/s]
# {'min': 359.9193382204805, 'max': 519.4383590947284, 'avg': 383.1081980853802, 'median': 376.3898325698281}
# 100%|██████████| 200/200 [00:17<00:00, 11.75it/s]
# {'min': 375.8640372739951, 'max': 519.4383590947284, 'avg': 401.5598042420841, 'median': 394.97232439140436}
# 100%|██████████| 200/200 [00:17<00:00, 11.16it/s]
# {'min': 395.2601525260487, 'max': 527.5001192084488, 'avg': 424.11790319959283, 'median': 414.89780696543926}
# 100%|██████████| 200/200 [00:21<00:00,  9.52it/s]
# {'min': 414.7240262377604, 'max': 531.8626506551088, 'avg': 445.74116086683824, 'median': 435.88415925491455}
# 100%|██████████| 200/200 [00:22<00:00,  8.88it/s]
# {'min': 434.15738007987386, 'max': 535.2543762412361, 'avg': 466.80422056333714, 'median': 457.9500916474683}
# 100%|██████████| 200/200 [00:21<00:00,  9.40it/s]
# (['C=CCC1Cc2cc(N)ccc2ONc2cccc(N)c2-c2ccccc2OCNc2ccc3cc2-c2cc(ccc2N)-c2c(N)cccc2-c2ccc(N)c(c2)Oc2cc(ccc2N)-c2cc(N)cc-3c2N1',
#   'CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONc1cccc(N)c1-c1ccccc1N',
#   'Cc1c(N)ccc2c1CNOc1cc(c3c(c1)-c1cc(N)cc(c1Nc1ccc4c(c1N)-c1cccc-4c1)-c1c(N)cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc1-c1ccc(O)c(O)c1-c1ccccc1-3)O2',
#   'CNCc1c(N)ccc2c1CNOc1cc(c3c(c1)-c1cc(N)cc(c1Nc1ccc4c(c1)-c1cccc-4c1)-c1c(N)cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc1-c1ccc(O)c(O)c1-c1ccccc1-3)O2',
#   'C#CCNc1cc(-c2ccccc2-c2c(N)cccc2NOc2c(C)cc(N)cc2CN)c2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1',
#   'CNc1cc2c3cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-3c1NCc1cc(N)cc(C)c1ONONc1cccc(N)c1-c1ccccc1-2',
#   'CCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1CN)-c1ccccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1Nc1ccccc1',
#   'CNc1cc2c3cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-3c1NCc1cc(N)cc(C)c1ONc1cccc(N)c1-c1ccccc1-2',
#   'CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1ccccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc2cc(C)c1ONNN2',
#   'CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONNNc1cccc(N)c1-c1ccccc1',
#   'CCc1c(N)ccc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4cc(N)cc(-c5ccccc5)c4)cc(N)c2-c2cc(N)cc-3c2Nc2ccc3c(c2)-c2ccc(N)c-3c2ON)c1CN',
#   'CNc1cc(-c2ccccc2-c2c(N)cccc2NOc2c(C)cc(N)cc2CN)c2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1N',
#   'CCCc1cc(N)ccc1ONc1cccc(N)c1-c1ccccc1Nc1cc2cc(c1N)Oc1cc(ccc1N)-c1cccc(N)c1-c1ccc(N)c(c1)-c1cc(ccc1N)-c1cccc-2c1NCN',
#   'CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ON',
#   'NNc1ccc2c(c1)CNOc1cc(c3c(c1)-c1cc(N)cc(c1Nc1ccc4c(c1)-c1cccc-4c1)-c1c(N)cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc1-c1ccc(O)c(O)c1-c1ccccc1-3)O2',
#   'C#CCCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)-c1ccccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1c3c(N)cc-2c1NN3CC#CC',
#   'CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONc1cccc(N)c1-c1ccccc1',
#   'CCc1cc(N)cc(CNc2c3cccc2-c2ccc(N)c(c2)-c2cc(ccc2N)-c2c(N)cccc2-c2ccc(N)c(c2)Oc2cc-3ccc2N)c1ONc1cccc(N)c1-c1ccccc1Nc1ccccc1',
#   'CCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1CN)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1',
#   'CCCc1cc(N)ccc1ONc1cccc(N)c1-c1ccccc1Nc1cc2cc(c1N)Oc1cc(ccc1N)-c1cccc(N)c1-c1ccc(N)c(c1)-c1cc(ccc1N)-c1cccc-2c1NCCN',
#   'CCNc1c2cc(N)cc1-c1ccc(NCN)c(c1)-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1ccc(N)cc1C)-c1c(N)cccc1-c1cc3c(N)c(c1)Oc1cc-2ccc1NO3',
#   'CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1ccccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONN',
#   'CNc1cc(-c2ccccc2-c2c(N)cccc2N)c2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ON',
#   'CNCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1ccccc1NOc1ccc(N)cc1C)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCN',
#   'Cc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1c3cc(N)c-2c1O3',
#   'CCc1cc(N)cc2c1ONc1cccc(N)c1-c1ccccc1Nc1cc3cc(c1N)Oc1cc(ccc1N)-c1cccc(N)c1-c1ccc(N)c(c1)-c1cc(ccc1N)-c1cccc-3c1NC2NN',
#   'CCCc1cc(N)cc(CNc2c3cccc2-c2ccc(N)c(c2)-c2cc(ccc2N)-c2c(N)cccc2-c2ccc(N)c(c2)Oc2cc-3ccc2N)c1ONc1cccc(N)c1-c1ccccc1N',
#   'CNc1cc(-c2ccccc2-c2ccccc2N)c2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONN',
#   'CCCc1cc(N)cc2c1ONc1cccc(N)c1-c1ccccc1Nc1cc3cc(c1N)Oc1cc(ccc1N)-c1cccc(N)c1-c1ccc(N)c(c1)-c1cc(ccc1N)-c1cccc-3c1NC2',
#   'CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1ccccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONNN',
#   'Cc1c(N)ccc2c1CNc1cc(c3c(c1)-c1cc(N)cc(c1Nc1ccc4c5c1Nc1ccc-5cc1-4)-c1c(N)cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc1-c1ccc(O)c(O)c1-c1ccccc1-3)O2',
#   'CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NN',
#   'CCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1ccccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ON',
#   'CC#CCCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)-c1ccccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1c3c(N)cc-2c1NN3',
#   'CNCNc1ccccc1-c1c(N)ccc2c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1CNc1ccc(N)cc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc(N)c1-2',
#   'CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)ccc1ONc1cccc(N)c1-c1ccccc1N',
#   'CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1ccc3c-2c1NCc1cc(N)cc(C)c1ONc1cccc(N)c1-c1ccccc1N3',
#   'CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1N',
#   'Cc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)cc(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1ON',
#   'CCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1ccccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1-c1ccc2c(c1)Nc1ccc-2cc1N',
#   'CCCc1cc(N)cc(C)c1ONc1cccc(N)c1-c1ccccc1Nc1cc2cc(c1N)Oc1cc(ccc1N)-c1cccc(N)c1-c1ccc(N)c(c1)-c1cc(ccc1N)-c1cccc-2c1NNN',
#   'C#CCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cccc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1ONc1cccc(-c2ccccc2)c1N',
#   'CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONc1ccccc1-c1ccccc1N',
#   'CCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1CN)-c1c(N)cccc1-c1cc3oc4cc(ccc4N)c4cc(N)cc-2c4c(c1)c3N',
#   'CNc1ccc2cc1-c1c(N)ccc3c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1CNc1c(cc(N)cc1-2)-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc(N)c1-3',
#   'CC(C)CCNCCc1cc(N)ccc1ONc1ccccc1-c1ccccc1-c1c2ccc(N)c1-c1cc(ccc1N)-c1cc(N)cc(c1NCN)-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc(N)c1-2',
#   'CCc1cc(N)cc(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3ccc(N)cc3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1Nc1ccc2cc1N2',
#   'CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc-2c1NCc1cc(N)cc(C)c1ONc1cccc(N)c1-c1ccccc1N',
#   'CNCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1ccc(N)cc1C)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NC',
#   'C=CCCCc1cc(N)ccc1ONc1cccc(N)c1-c1ccccc1OCNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1N',
#   'Cc1cc(N)cc(CNc2c3cc(N)cc2-c2ccc(N)c(c2)-c2ccccc2Nc2ccccc2Nc2ccc(-c4cccc(N)c4)cc2Oc2cc-3ccc2N)c1ONc1cccc(N)c1-c1ccccc1N',
#   'CCc1cc(N)c(C)c(C)c1OCNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ON',
#   'CNCNc1cc(-c2ccccc2-c2c(N)cccc2NOc2c(C)cc(N)cc2CN)c2cc1-c1cccc(c1)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1N',
#   'CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc-2c1NCc1cc(N)cc(C)c1ONc1cccc2c1-c1ccccc1NN2',
#   'CCCc1cc(N)cc2c1ONc1cc3cc(N)c1-c1ccccc1Nc1cc4cc(c1N)Oc1cc(ccc1N)-c1cccc(N)c1-c1ccc(N)c(c1)-c1cc(ccc1N)-c1cccc-4c1NC32',
#   'CCc1cc(N)cc(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cccc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1OO',
#   'CC(N)OCNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONc1ccccc1-c1ccccc1NN',
#   'CC(C)CCCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1CN)C=C1C=CC=CNc3c(cc(N)cc3-2)-c2ccc(N)c(c2)Oc2cc1ccc2N',
#   'C#CCc1cc(N)cc(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cccc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1ONc1cccc(-c2ccccc2)c1NN',
#   'CCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1CN)-c1c3cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1N3',
#   'CCNc1c2cc3c(-c4ccccc4)c1Nc1c(N)cccc1NOc1c(C)cccc1CNc1c(cc(N)cc1-3)-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc(N)c1-c1ccc(N)c-2c1',
#   'CCNc1cc(-c2ccccc2-c2c(N)cccc2N)c2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(C)cc(N)c1',
#   'CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)-c1c3cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NNN3',
#   'C#CCc1c2c(C)c(C)c(N)c1N1c3cc(c4c(c3C)C3Oc5c(N)cccc5NCc5cc(N)cc(CN)c5Oc5ccc(c(-c6ccccc6)c51)-c1ccc(c(N)c13)-c1cccc(c1)-c1cccc(c1)O4)CO2',
#   'CC#CCCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)-c1ccccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NN',
#   'Cc1cc(N)cc2c1ONc1cccc(N)c1-c1ccccc1-c1cc(N)c3cc1C=CC(N)=CC(=CNC2)c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc(N)c1-c1ccc(N)c-3c1N',
#   'C=CCCc1c(N)ccc2c1CNc1cc(c3c(c1)-c1cc(N)cc(c1NC1=CNc4ccc5cc4C(=C5)C=C1)-c1c(N)cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc1-c1ccc(O)c(O)c1-c1ccccc1-3)O2',
#   'Cc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1Nc1cccc2c1Nc1ccc-2cc1N',
#   'CNCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1ccc(N)cc1C)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NN',
#   'CCNc1ccc2cc1c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1CN)c1c3cccc1c1ccccc1[nH]c1c(cc(N)cc21)c1ccc(N)c(c1)oc1cc3ccc1N',
#   'CC(C)CCc1cc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc(N)c2-c2cc(N)cc-3c2Nc2ccc3c(c2)-c2ccc(N)c-3c2)ccc1NN',
#   'Cc1cccc(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1OONN',
#   'Cc1c(N)ccc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc(N)c2-c2cc(N)cc-3c2Nc2ccc3c4c2Nc2ccc-4cc2-3)c1CN',
#   'CCc1cc(N)cc(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3ccc(N)cc3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1Nc1ccccc1N',
#   'CNCCc1cc(N)cc2c1ONc1cccc(N)c1-c1ccccc1-c1cc(N)ccc1-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc(-c3cccc(NC=O)c3)c1NC2',
#   'CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc-2c1NCc1cc(N)cc(C)c1ONNO',
#   'CNCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1ccc(N)cc1C)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1N',
#   'CCNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc-2c1NCc1cc(N)cc(C)c1ONc1cccc(NN)c1-c1ccccc1',
#   'C#CCNc1ccc2cc1-c1cccc(c1)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1ccc3c-2c1NCc1cc(N)cc(C)c1ONc1cccc(N)c1-c1ccccc1N3N',
#   'CCNONc1cc2c(Nc3ccc4c(c3N)-c3cccc-4c3)c(c1)-c1c(N)cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc1-c1ccc(O)c(O)c1-c1ccccc1-c1c(Oc3ccc(N)c(C)c3)cccc1-2',
#   'CC(=O)OCNc1cc2c3cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)C1=CNCc4cc(N)cc(C)c4ONc4c(ccc(N)c4-c4ccccc4-2)C3=CC(N)=C1',
#   'CNCc1cc(N)c(C)c(C)c1ONc1cc2c(Nc3ccc4c5c3Nc3ccc-5cc3-4)c(c1)-c1c(N)cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc1-c1ccc(O)c(O)c1-c1ccccc1-c1ccccc1-2',
#   'CCCCc1cc(N)cc(CNc2c3cccc2-c2ccc(N)c(c2)-c2cccc(c2)-c2c(N)cccc2-c2ccc(N)c(c2)Oc2cc-3ccc2N)c1ONc1cccc(N)c1-c1ccccc1N',
#   'Cc1cc(N)cc(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1OO',
#   'Cc1c(N)ccc2c1CNONc1cc3c(Nc4ccc5c(c4N)-c4cccc-5c4)c(c1)-c1c(N)cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc1-c1ccc(O)c(O)c1-c1ccccc1-c1c(cccc1-3)O2',
#   'CCc1cc(N)cc2c1ONc1cccc(N)c1-c1ccccc1-c1cc(NCOC=O)c3cc1C=CC(N)=CC(=CNC2)c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc(N)c1-c1ccc(N)c-3c1',
#   'CCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1ccccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1c1cc2c3c(c1)-c1cc-3ccc1N2',
#   'CC#CCCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)-c1ccccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc-2cc(N)c1NNO',
#   'Cc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1O',
#   'CC(=O)OCNc1cc2c3cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)C(=CNCc1cc(N)cc(C)c1ONc1cccc(N)c1-c1ccccc1-2)C=C(N)C=C3',
#   'CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cccc1C)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NN',
#   'CC(=O)OCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)-c1c(N)cccc1-c1cccc(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCC=O',
#   'CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1ccccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cccc(c1)-c1cc(N)cc-2c1NCc1cc2cc(C)c1ONNN2N',
#   'C1CCCCC1CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc-2c1NCc1cc(N)cc(C)c1ONc1cccc(NN)c1-c1ccccc1',
#   'CC#CCCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)-c1ccccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc-2c1NNN',
#   'CNCN(C)CCc1cc(N)cc(CNc2c3cc(N)cc2-c2ccc(N)c(c2)Oc2cc(ccc2N)-c2cccc(N)c2-c2cccc(c2-c2ccccc2-c2ccccc2N)-c2cccc-3c2)c1ONNO',
#   'CNc1cc(-c2ccccc2)c2cc1-c1cccc(c1)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONc1cccc(N)c1NN',
#   'CCNc1cc(-c2ccccc2)c2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cccc(C)c1ONc1cccc(N)c1N',
#   'CCNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1ccc3c-2c1NCc1cc(C)cc(N)c1-c1cc(N)c(c(NO)c1)-c1ccccc1N3',
#   'CCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3ccc(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1O',
#   'CC1=CCNc2cc3occcc1[nH]oc1cccc(c1)c1cc(cc(N)c1N)c1cc(N)c4c(c1)-c1ccc(O)c(O)c1-c1ccccc1-c3c(c2)c1cc(N)cc4c1Nc1ccc2c3c1Nc1ccc-3cc1-2',
#   'Cc1cc(N)cc(CN)c1ONc1cccc(N)c1-c1ccccc1-c1c2ccc(N)c1-c1cccc(c1)-c1cc(N)cc3c1Nc1cccc(c1-2)-c1ccc(N)c(c1)Oc1cc-3ccc1NN',
#   'Cc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c3c1Nc1ccc-3cc1-2',
#   'CNc1cc2c3cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-3c1NN(Oc1c(C)cc(N)cc1CN)c1cccc(N)c1-c1ccccc1-2',
#   'CC(=O)OCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)-c1c(N)cccc1-c1cccc(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NNN',
#   'C=CCCc1cc(N)c(C)cc1Oc1c2c3ccc1[nH]c1cc4cc5ccc([nH]cc-1[nH]c1c(cc(N)cc31)-c1c(N)cc(-c3cc(N)c(N)c(-c6ccccc6)c3)cc1-c1ccc(O)c(O)c1-c1ccccc1-2)c-4c5',
#   'CCCc1cc(N)cc(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c3c1Nc1ccc-3cc1-2',
#   'CCc1c(N)ccc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc(N)c2-c2cc(N)cc-3c2Nc2cccc3c2Nc2ccc-3cc2)c1CN',
#   'CCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3ccc(N)cc3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1Nc1ccccc1',
#   'CNc1ccc2cc1-c1ccccc1Nc1ccccc1Nc1ccc(-c3cccc(N)c3)cc1Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONc1cccc(N)c1-c1ccccc1',
#   'CCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)ccc1ONN',
#   'CCc1cc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc(N)c2-c2cc(N)cc-3c2Nc2ccc3c4c2Nc2ccc-4cc2-3)c(C)cc1N',
#   'CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1ccc3c-2c1NCc1cc(N)ccc1ONc1cccc(N)c1-c1ccccc1N3N',
#   'CC(N)OCNc1cc(-c2ccccc2-c2ccccc2N)c2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ON',
#   'CC(C)CCCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3ccc(N)cc3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1NN',
#   'C=CCCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1NC1=CNc2ccc3cc2C2=C3C1=C2',
#   'CNc1ccc2cc1-c1ccccc1Nc1ccccc1Nc1ccc(-c3cccc(N)c3)cc1Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc2cc(C)c1o[nH]c1cccc(N)c1c1ccccc1[nH]2',
#   'Cc1cc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc(N)c2-c2cc(N)cc-3c2Nc2ccc3c4c2Nc2ccc-4cc2-3)ccc1NN',
#   'COC(C)NCc1cc(N)cc(CNc2c3cc(N)cc2-c2cc(c(N)cc2-c2ccccc2-c2ccccc2N)-c2cc(ccc2N)-c2c(N)cccc2-c2ccc(N)c(c2)Oc2cc-3ccc2N)c1ONN',
#   'CC(=O)OCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)-c1c(N)cccc1-c1cccc(c1)Oc1cc(ccc1N)-c1cccc-2c1NNNN',
#   'CCNc1ccc(-c2cc(N)cc3c2Nc2cccc(c2)-c2ccc(N)c(c2)Oc2cc-3ccc2N)cc1-c1c(N)cccc1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1CNN',
#   'C#CCNCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(O)cccc1-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1',
#   'C#CCNCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(O)cccc1-c1cc(-c3ccc(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1N',
#   'Cc1cc(N)c(C)c(C)c1Oc1cccc(-c2cc(N)ccc2Nc2ccc3c4c2Nc2ccc-4cc2-3)c1-c1ccccc1-c1c2ccc(O)c1ONc1cccc(c1)-c1cc(cc(N)c1N)-c1cc(N)cc-2c1N',
#   'CNc1cc(-c2ccccc2)c2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONc1cccc(N)c1N',
#   'CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONc1cccc(N)c1N',
#   'C=CCCCc1cc(N)ccc1ONc1cccc(N)c1-c1ccccc1OCNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc-2c1NO',
#   'C#CCc1cc(N)cc(C)c1Oc1cccc2c1-c1ccccc1C=C(O)C(O)=CC=Cc1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1OO',
#   'CC#CCCNc1ccc(-c2cc(N)c3c(-c4ccc(N)c(Oc5cc(-c6ccccc6)ccc5N)c4)c2NN3)cc1-c1c(N)cccc1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1CN',
#   'Cc1cc(N)c(C)c(C)c1OCc1cc(N)c2cc1Oc1cccc(-c3cc(N)cc4c3NOc3ccc5c(C)c3CN5Oc3ccc(cc3-c3ccccc3)-c3ccc-4c(N)c3)c1C2CNOOc1c2cccc1-2',
#   'CCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1ccc(N)cc1C)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cccc(c1)-c1cc(N)cc-2c1OCNCN(C)C',
#   'Cc1cc(N)c(C)c(C2c3c4ccc(c3N)-c3ccc(c(N)c32)-c2ccccc2Oc2ccccc2Oc2ccccc2-c2cc-4cc(N)c2N)c1OCc1cc(N)c(C)c2c1Oc1ccccc1C2c1ccccc1',
#   'Cc1cc(N)cc(CNc2c3cccc2-c2ccc(NCCC(C)C)c(c2)-c2c(N)ccc(c2-c2ccccc2)-c2c(N)cccc2-c2ccc(N)c(c2)Oc2cc-3ccc2N)c1ON1NOc2c(N)cccc21',
#   'CCCc1c(N)ccc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc(N)c2-c2cccc-3c2Nc2ccc3c4c2Nc2ccc-4cc2-3)c1CN',
#   'C#CCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)C=C(N)C=CC=Cc1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1N',
#   'CCCc1c(N)ccc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4ccc(N)c(N)c4)cc(N)c2-c2cc(N)cc-3c2Nc2ccc3c4c2Nc2ccc-4cc2-3)c1Cc1cc2ccc1-2',
#   'Cc1c(N)ccc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4ccc(N)c(N)c4)cc(N)c2-c2cc(N)cc-3c2Nc2ccc3c(c2)-c2ccc(N)c-3c2)c1Cc1ccccc1N',
#   'C#CCNCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(O)cccc1-c1cc(-c3cc(N)cc(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1N',
#   'C#CCc1cc(N)c(C)c(C)c1OCc1cc2c(C)c3c1Oc1cccc(c1)-c1cccc(c1)-c1ccc4c(c1N)C3Oc1c(N)cccc1NCc1cc(N)cc(CN)c1Oc1ccc-4c(-c3ccccc3)c1N2',
#   'C=CCCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1NC1=CNc2ccc3cc2C(=C3)C=C1',
#   'CC#CCCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)-c1ccccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc-2c1NNNO',
#   'Cc1c(N)ccc2c1Cc1ccccc1Nc1c(-c3ccc(N)c(N)c3)cc3c(c1N)-c1cc(N)cc(c1Nc1ccc4c(c1)-c1ccc(N)c-4c1)-c1cccc(c1-c1ccccc1-c1c-3ccc(O)c1O)O2',
#   'C#CCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)ccc1-c1cc(N)cc-2c1Nc1ccc(-c2ccccc2)cc1N',
#   'Cc1cc(N)c(C)c(C)c1OCc1cc(N)c2cc1Oc1cccc(-c3cc(N)cc4c3NOc3ccc5c(C)c3CN5Oc3ccc(cc3-c3ccccc3)-c3ccc-4c(N)c3)c1C2CNOc1c2cccc1-2',
#   'C=CCCc1cc(N)c(C)cc1Oc1c2c3ccc1[nH]c1cc4cc5ccc([nH]cc-1[nH]c1c(cc(N)cc31)-c1c(N)cc(-c3ccc(N)c(-c6ccccc6)c3)cc1-c1ccc(O)c(O)c1-c1ccccc1-2)c-4c5O',
#   'C=CCCc1cc(N)c(C)cc1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1c3[nH]c4cc5cc6ccc([nH]cc-4[nH]c4c-2cc(N)cc4c1c(N)cc3-c1cc(N)c(N)c(-c2ccccc2)c1)c5c6',
#   'CNCNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc2cc(C)c1ONNN2',
#   'Cc1cc(N)c(C)c2c1OCc1cc(N)c(C)c3c1Oc1ccccc1C3c1ccccc1Nc1c3ccc4c1C2c1c(ccc-4c1N)-c1cc(N)c(N)c(c1)-c1ccccc1Oc1ccccc1Oc1ccccc1-3',
#   'CCc1c(Oc2cccc(-c3cc(N)ccc3Nc3cccc4c3Nc3ccc-4cc3)c2-c2ccccc2)c(C)c(C)c(N)c1-c1c2cc(N)cc1-c1cc(N)c(N)c(c1)-c1cccc(c1)NOc1cc-2ccc1ON',
#   'CNc1ccc2cc1-c1cccc(c1-c1ccccc1-c1ccccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1Cc1cc(N)cc(CN)c1ONNON',
#   'C#CCCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)ccc1-c1cc(N)cc-2c1Nc1ccc(-c2ccccc2)cc1N',
#   'CNCc1cc(N)c(C)c(C)c1OCc1cc(N)c2cc1Oc1cccc3c1C2CNc1ccccc1-c1cccc(c1)-c1cc(-c2ccc(ON4Cc5c(ON)ccc4c5C)cc2)cc(N)c1-c1cc(N)cc-3c1',
#   'C#CCNCc1cc(N)c(C)c(C)c1OCc1cc(N)c2cc1Oc1cccc3c1C2c1cccc(c1)-c1cc2cc(N)c1-c1cc(N)cc-3c1NOc1ccc3c(C)c1CN3Oc1ccc-2cc1-c1ccccc1',
#   'Cc1cc(N)c(C)c(C)c1OCc1cc(N)c2cc1Oc1cc3cc4c1ONC2C1c2cc5c(C)c(c2O)CN5Oc2ccc(cc2-c2ccccc2)-c2cc(N)c(c(-c5ccccc5)c2)-c2cc(N)cc-4c2N31',
#   'CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1cccc(c1)Oc1cc(ccc1N)-c1cccc-2c1NCc1cc(N)cc(C)c1ONc1cccc2c1-c1ccccc1NN2N',
#   'CCCc1cc(N)cc2c1ONc1cccc(N)c1-c1ccccc1Nc1cc(cc(Oc3cc(-c4cccc(N)c4-c4ccc(N)c(-c5ccccc5N)c4)ccc3N)c1N)-c1ccccc1NC2N',
#   'Cc1cc(N)c(C)c(C)c1Oc1cccc(-c2cc(N)ccc2Nc2ccc3c4c2Nc2ccc-4cc2-3)c1-c1ccccc1-c1c2o[nH]c3cccc(c3)c3cc(cc(N)c3N)c3cc(N)cc4c3-c(cc14)c2O',
#   'CNc1ccc2cc1-c1cccc(c1)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)ccc1ONc1cccc(N)c1-c1ccccc1NNNC=O',
#   'CCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc3cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1Oc1cccc(c1)-c1cc-3ccc1N',
#   'CCNc1c2cc(N)cc1-c1ccc(NCN)c(c1)-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1NOc1ccc(N)cc1C)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc-2ccc1NO',
#   'CCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1ccccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc3cc-2c1-c1cc2c4c(c1)c1cc-4ccc1n-2-n-3',
#   'Cc1cc(N)c(C)c2c1Oc1cccc(c1)-c1cccc(c1)-c1c(-c3ccccc3NN)cc3c(c1N)C2Oc1c(N)cccc1NCOc1ccc(N)cc1CNNc1cccc(c1)-c1ccccc1-3',
#   'CCc1cc(N)c(C)c(C)c1Oc1cccc(-c2cc(N)ccc2Nc2ccc3c4c2Nc2ccc-4cc2-3)c1-c1ccccc1-c1c2cccc1-c1cc(N)cc(c1)-c1cc(N)c(N)c(c1)-c1cccc(c1)NO2',
#   'C=CCCCc1cc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4ccc(N)c(-c5ccccc5)c4)cc(N)c2-c2cc(N)cc-3c2Nc2ccc3c4c2Nc2ccc-4cc2-3)c(C)cc1NN',
#   'CNc1ccc(-c2cc(N)cc3c2NCc2cc(N)cc(C)c2ONc2cccc(N)c2-c2ccccc2-c2cc(N)ccc2-c2c(N)cccc2-c2ccc(N)c(c2)Oc2cc-3ccc2N)cc1NC=O',
#   'C=CCCc1cc(N)c(C)cc1Oc1c2c3ccc1[nH]c1cc4cc5ccc6[nH]cc1[nH]c1c3cc(N)cc1c1c(N)cc(-c3cc(N)c(N)c(-c7ccccc7)c3)c(c1-c1ccc(O)c(O)c1-c1ccccc1-2)c5c46',
#   'C=CCCc1cc(N)c(C)cc1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)cc-2c1NC1=CNc2ccc3cc2C(=C3)C=C1N',
#   'CCNc1ccc2cc1c1c(N)ccc3c1-c1cc(ccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1CN)-o-c1c(cc(N)cc12)c1cccc(c1)oc1cc(ccc1N)c1cccc(N)c31',
#   'CCc1cc(N)c2c(C)c1Oc1ccc(N)c(-c3cc(-c4c(N)cc(-c5ccccc5)cc4-c4ccc(O)c(O)c4)cc(N)c3-c3ccccc3)c1Nc1cccc(-c3ccccc3)c1Oc1ccccc1OCN2',
#   'CC#CCCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1)-c1ccccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1c3c(N)cc-2c1NN3Cc1cc(N)cc(C)c1ONc1cccc(N)c1N',
#   'Cc1ccc(C)c(OCc2cc(N)c3cc2Oc2cccc(-c4cc(N)cc5c4NOc4ccc6c(C)c4CN6Oc4ccc(cc4-c4ccccc4)-c4ccc-5c(N)c4)c2C3CNOc2c3cccc2-3)c1CN',
#   'CCCc1cc(N)c(C)cc1Oc1cccc(-c2cc(N)ccc2Nc2cccc3c2Nc2ccc-3cc2)c1-c1ccccc1-c1c2ccc(O)c1ONc1cccc(c1)-c1cc(cc(N)c1N)-c1cc(N)cc-2c1N',
#   'Cc1c(N)ccc2c1CNc1cc(cc(N)c1N)-c1cc(N)c3c(c1)-c1ccc(O)c(O)c1-c1ccccc1-c1c(cccc1-c1cc(N)cc-3c1Nc1ccc3c4c1Nc1ccc-4cc1-3)O2',
#   'Cc1cc(N)c(C)c(C)c1OCc1cc(N)c2cc1Oc1cc3cc4c1ONC2Cc1cc2c(C)c(c1O)CN2Oc1ccc(cc1-c1ccccc1)-c1cc(N)c(c(-c2ccccc2)c1)-c1cc(N)cc-4c1N3',
#   'C#CCCc1cccc(C)c1OCc1cc2oc3c4c(ccc3[nH]c1cc2C)-c1c(Nc2cccc(-c3ccccc3)c2N)c(cc(N)c1-c1ccccc1)-c1c(N)cccc1-c1ccc(O)c(O)c1-c1ccccc1-4',
#   'CCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3ccc(N)c(N)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1N',
#   'C#CCNc1c2c(C)c3c(C)c1C(NNc1ccccc1-c1ccccc1NNOO2)c1ccccc1-c1cc(-c2ccc(-c4cc(N)c(O)c(N)c4O)cc2-c2ccccc2)cc(N)c1-c1cccc(c1)NO3',
#   'CCNc1cc(-c2ccccc2)c2cc1-c1cccc(c1)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cccc(C)c1ONc1cccc(N)c1NN',
#   'Cc1cc(N)c(C)c(C)c1Oc1cccc2c1Nc1ccccc1-c1cccc(c1)-c1c(ccc(O)c1O)-c1c3c(N)cc(-c4cc(N)c(N)c(-c5ccccc5)c4)c1-c1c-3cc(N)c(-c3ccccc3)c1-2',
#   'Cc1c(N)ccc2c1CNc1ccccc1-c1cc3ccc1ON1Cc4c(C)c1cc(c4O)CC1NOc4c(cccc4-c4cc(N)cc(c4N)-c4c(N)cc-3cc4-c3ccccc3)Oc3cc1c(N)cc3CO2',
#   'Cc1cc2c(C)c3c1Oc1cccc(c1)-c1cccc(c1)-c1c(-c4ccccc4NN)ccc(c1N)C3Oc1c(N)cccc1NCc1cc(N)cc(CN)c1Oc1cccc(-c3ccccc3)c1N2c1ccccc1',
#   'CCCc1c(N)ccc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4ccc(N)c(N)c4)cc(N)c2-c2cc(N)cc-3c2Nc2ccc3c4c2Nc2ccc-4cc2-3)c1Cc1ccccc1',
#   'NNc1ccc2cc1Nc1ccc3cc1Oc1ccc(cc1-2)-c1ccc(c(N)c1)-c1cc(N)c2c-3c1-c1c-2cc2c(N)c1-c1ccccc1-c1c(N)cccc1Nc1c(cccc1-c1ccccc1)N2',
#   'Cc1cc(N)c(C)c(C)c1Oc1cccc2c1Nc1ccccc1-c1cccc(c1)-c1c(ccc(O)c1O)-c1cc(-c3cc(N)c(N)c(-c4ccccc4)c3)cc(N)c1-c1cc(N)c(-c3ccccc3)c-2c1',
#   'C#CCCc1cc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc(N)c2-c2cc(N)cc-3c2Nc2ccc(-c3ccccc3)cc2)c(C)cc1N',
#   'CC(=O)OCNc1ccc2cc1-c1c3ccc(c1-c1ccccc1-c1c(N)cccc1NOc1c(C)cc(N)cc1C)-c1c(N)cccc1-c1cccc(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NNNN3',
#   'Cc1c(N)ccc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4ccc(N)c(N)c4)cc(N)c2-c2cc(N)cc-3c2Nc2ccc3c4c2Nc2ccc-4cc2-3)c1Cc1ccccc1',
#   'Cc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c3cc(c(O)c1O)Oc1c4ccc(N)c1-c1ccc(cc1-4)Nc1c-2cc(N)cc1C1C3=CC1(C=CN)c1cc(N)c(N)c(-c2ccccc2)c1N',
#   'Cc1cc(N)cc2c1Oc1cccc(c1)-c1cccc(c1)-c1c(-c3ccccc3NN)cc3c(c1N)C2Oc1c(N)cccc1NCc1cc(N)cc(CN)c1ONc1ccc(cc1)-c1ccccc1-3',
#   'Cc1cc(Oc2cccc3c2-c2ccccc2-c2c(ccc(O)c2O)-c2cc(-c4cc(N)c(N)c(-c5ccccc5)c4)cc(N)c2-c2cc(N)cc-3c2Nc2cccc3c2Nc2ccc-3cc2)ccc1NNN',
#   'Cc1cc(N)c(C)c(C2c3c4ccc(c3N)-c3ccc(c(NC5c6ccccc6Oc6c(C)cc(N)c(C)c65)c32)-c2ccccc2Oc2ccccc2Oc2ccccc2-c2cc-4cc(N)c2N)c1Oc1ccccc1',
#   'CCNCNc1ccc(-c2c3ccc(-c4ccc(N)c(Oc5cc(-c6cccc(N)c6)ccc5N)c4)c2NCc2cc(N)cc(C)c2ONc2cccc(N)c2-c2ccccc2N3)cc1-c1ccccc1N',
#   'CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cccc-2c1NCc1cc(N)cc(C)c1ONc1cccc(N)c1ONN',
#   'CCCCc1cc(N)cc(CNc2c3cccc2-c2ccc(N)c(c2)-c2cccc(c2)-c2c(N)cccc2-c2cccc(c2)Oc2cc-3ccc2N)c1ONc1cccc(N)c1-c1ccccc1NN',
#   'CCCCc1cc(N)cc(CNc2c3cccc2-c2ccc(N)c(c2)-c2cccc(c2)-c2c(N)cccc2-c2ccc(N)c(c2)Oc2cccc-3c2)c1ONc1cccc(N)c1-c1ccccc1NN',
#   'Cc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc(-c3ccc(N)c(N)c3)cc(N)c1-c1cc(N)cc-2c1Nc1ccc2c(c1)-c1ccc(N)c-2c1ON',
#   'CNc1cc(-c2ccccc2-c2c(N)cccc2N)c2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONO',
#   'CCc1cc(N)c(C)c(C)c1Oc1cccc2c1-c1ccccc1-c1c(ccc(O)c1O)-c1cc3cc(N)c1-c1cc(N)cc-2c1-n-c1ccc2c(c1)-c1ccc(N)c-2c1-o-c1ccccc1-c1cc-3ccc1N',
#   'Cc1cc(N)cc2c1Oc1cc3cc(c1)-c1cccc(c1)-c1c(-c4ccccc4NN)cc(-c4ccccc4-c4ccccc4)c(c1N)C2Oc1c(N)cccc1NCc1cc(N)cc(CN)c1ON3',
#   'Cc1cc(N)c(C)c(C)c1Oc1cccc(-c2cc(N)ccc2Nc2ccc3c4c2Nc2ccc-4cc2-3)c1-c1ccccc1-c1c2o[nH]c3cccc(c3)c3cc(cc(N)c3N)c3cc(N)c4c(c3-4)c1ccc2O'],
#  [{'min': -18.627716952186717,
#    'max': 341.82751146461203,
#    'avg': 155.0205943069376,
#    'median': 192.30471646230126},
#   {'min': 0.32924627539441076,
#    'max': 372.00136281639135,
#    'avg': 193.75069924046727,
#    'median': 233.03262860226732},
#   {'min': 260.70775889861363,
#    'max': 417.29783382444884,
#    'avg': 306.33300754621405,
#    'median': 303.63735628202573},
#   {'min': 314.0653048449017,
#    'max': 417.29783382444884,
#    'avg': 340.5848931659966,
#    'median': 335.2604619448733},
#   {'min': 340.5805255776993,
#    'max': 437.25360514841145,
#    'avg': 364.2421495210327,
#    'median': 358.9107081943385},
#   {'min': 359.9193382204805,
#    'max': 519.4383590947284,
#    'avg': 383.1081980853802,
#    'median': 376.3898325698281},
#   {'min': 375.8640372739951,
#    'max': 519.4383590947284,
#    'avg': 401.5598042420841,
#    'median': 394.97232439140436},
#   {'min': 395.2601525260487,
#    'max': 527.5001192084488,
#    'avg': 424.11790319959283,
#    'median': 414.89780696543926},
#   {'min': 414.7240262377604,
#    'max': 531.8626506551088,
#    'avg': 445.74116086683824,
#    'median': 435.88415925491455},
#   {'min': 434.15738007987386,
#    'max': 535.2543762412361,
#    'avg': 466.80422056333714,
#    'median': 457.9500916474683}])

# %%
new_mols_df = pd.read_csv('gen_algo_cache/population_mol_based.csv')
new_mols_df = new_mols_df[~new_mols_df.SMILES.isin(initial_molecules)]

# %%
new_mols_df.head(10)
# Out:
#                                               SMILES   pred_pdsc
# 0  CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(...  535.254376
# 1  Cc1c(N)ccc2c1CNOc1cc(c3c(c1)-c1cc(N)cc(c1Nc1cc...  531.862651
# 2  CNCc1c(N)ccc2c1CNOc1cc(c3c(c1)-c1cc(N)cc(c1Nc1...  531.357580
# 3  CNc1cc2c3cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c...  530.285149
# 4  CCNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1...  529.216314
# 5  CNc1cc2c3cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c...  527.500119
# 6  CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1ccccc1N)-c...  524.665640
# 7  CNc1cc(-c2ccccc2-c2c(N)cccc2NOc2c(C)cc(N)cc2CN...  521.775853
# 8  CNc1ccc2cc1-c1c(N)ccc(c1-c1ccccc1-c1c(N)cccc1N...  520.850048
# 9  CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(...  519.438359

# %%
new_mols_df = new_mols_df[(~new_mols_df['SMILES'].apply(lambda el: '.' in el)).tolist()]
new_mols_df = new_mols_df[~new_mols_df['SMILES'].isin(initial_molecules)]

# %%
new_mols_df['SMILES'].head(15).to_csv('submit.csv', encoding='UTF-8', index=False)

# %%
import os
import zipfile
with zipfile.ZipFile('submission.zip', 'w', zipfile.ZIP_DEFLATED) as zipf:
    zipf.write('submit.csv', os.path.basename('submit.csv'))
    # zipf.write('4_ml_PDSC_prediction.ipynb', os.path.basename('4_ml_PDSC_prediction.ipynb'))
    zipf.write('6_genetic_algo_graph_based.ipynb', os.path.basename('6_genetic_algo_graph_based.ipynb'))
    zipf.write('src/utils.py', os.path.basename('src/utils.py'))

# %%
sa_score('CNc1ccc2cc1-c1cc(ccc1N)-c1c(N)cccc1-c1ccc(N)c(c1)Oc1cc(ccc1N)-c1cc(N)cc-2c1NCc1cc(N)cc(C)c1ONc1cccc(N)c1-c1ccccc1N')
# Out:
# 6.1090883795804976
